# %% [markdown]
# You should have trained the three Random Forest models for the molecules: CH4_RF, O3_RF, and H2O_RF. These should have been saved as joblib files in the format `"mol_name"_rf_S|C.joblib`.

# %%
import multirex as mrex
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sys
import pandas as pd
from tqdm import tqdm
import os
import re
import gc

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

from sklearn.exceptions import DataConversionWarning
import warnings

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import  ConfusionMatrixDisplay
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score
## general metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
# accuracy, f1 , recall, precision
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score
## hamming loss and exact match
from sklearn.metrics import hamming_loss, accuracy_score

#%matplotlib inline

def remove_warnings():
    warnings.filterwarnings("ignore", category=DeprecationWarning)
    warnings.filterwarnings(action='ignore', category=DataConversionWarning)

#load txt waves.txt
waves=np.loadtxt("waves.txt")
n_points = len(waves)
indices = np.linspace(0, len(waves) - 1, n_points, endpoint=True)
indices = np.round(indices).astype(int)  # Redondear los índices y convertir a entero

# Seleccionar los elementos de la lista usando los índices
puntos_seleccionados = waves[indices]
waves=puntos_seleccionados
wn_grid=np.sort((10000/waves))
# Out:
# Numba not installed, using numpy instead
# Loading MultiREx version 0.3.2

# %%
def apply_contaminations_from_files(
    contamination_files, df, n_points,
):
    """
    Aplica múltiples contaminaciones a los datos desde una lista de archivos de contaminación
    y devuelve un DataFrame con todas las combinaciones, incluyendo el caso sin contaminación.

    Parámetros:
        contamination_files (list de str): Lista de rutas a archivos .txt con contaminaciones.
        df (pandas.DataFrame): DataFrame original sobre el cual se aplicarán las contaminaciones.
        n_points (int): Número de columnas a las que se aplicará la contaminación.

    Retorna:
        pandas.DataFrame: DataFrame con todas las combinaciones de contaminaciones,
                          incluyendo sin contaminación, y con columnas adicionales 'f_spot' y 'f_fac'.
    """
    # Lista para almacenar los DataFrames resultantes
    df_list = []

    # Caso sin contaminación
    df_no_contam = df.copy()
    df_no_contam['f_spot'] = 0.0
    df_no_contam['f_fac'] = 0.0
    # Reordenar columnas para que 'f_spot' y 'f_fac' estén al inicio
    cols = ['f_spot', 'f_fac'] + [
        col for col in df_no_contam.columns if col not in ['f_spot', 'f_fac']
    ]
    df_no_contam = df_no_contam[cols]
    df_list.append(df_no_contam)

    # Expresión regular para extraer f_spot y f_fac del nombre del archivo
    pattern = r"fspot(?P<f_spot>[0-9.]+)_ffac(?P<f_fac>[0-9.]+)\.txt$"

    for file_path in contamination_files:
        # Verificar que el archivo exista
        if not os.path.isfile(file_path):
            raise FileNotFoundError(f"El archivo {file_path} no existe.")

        # Extraer f_spot y f_fac del nombre del archivo
        filename = os.path.basename(file_path)
        match = re.search(pattern, filename)
        if not match:
            raise ValueError(
                f"El nombre del archivo '{filename}' no coincide con el patrón esperado."
            )

        f_spot = float(match.group('f_spot'))
        f_fac = float(match.group('f_fac'))

        # Leer los valores de contaminación desde el archivo txt
        try:
            # Cargar los datos asegurando que siempre haya al menos dos dimensiones
            contamination_data = np.loadtxt(file_path, ndmin=2)
            # Si la contaminación tiene al menos dos columnas, tomar la segunda
            if contamination_data.shape[1] >= 2:
                contam_values = contamination_data[:, 1]
            else:
                contam_values = contamination_data.flatten()

            # Verificar que la longitud de contam_values coincide con n_points
            if len(contam_values) != n_points:
                raise ValueError(
                    f"El número de valores de contaminación en '{filename}' ({len(contam_values)}) "
                    f"no coincide con n_points ({n_points})."
                )
        except Exception as e:
            raise ValueError(f"Error al leer el archivo {file_path}: {e}")
        contam_values = contam_values[::-1]
        # Crear una copia del DataFrame original
        df_contam = df.copy()

        # Aplicar la contaminación multiplicando las últimas n_points columnas por contam_values
        data_columns = df_contam.columns[-n_points:]
        # Multiplicar las columnas por contam_values (aplicación columnar)
        df_contam[data_columns] = df_contam[data_columns].multiply(contam_values, axis=1)

        # Añadir columnas 'f_spot' y 'f_fac'
        df_contam['f_spot'] = f_spot
        df_contam['f_fac'] = f_fac

        # Reordenar columnas para que 'f_spot' y 'f_fac' estén al inicio
        cols = ['f_spot', 'f_fac'] + [
            col for col in df_contam.columns if col not in ['f_spot', 'f_fac']
        ]
        df_contam = df_contam[cols]

        # Añadir el DataFrame contaminado a la lista
        df_list.append(df_contam)

    # Concatenar todos los DataFrames en uno solo
    df_final = pd.concat(df_list, ignore_index=True)

    # Definir atributos .data y .params en el DataFrame final
    df_final.data = df_final.iloc[:, -n_points:]
    df_final.params = df_final.iloc[:, :-n_points]

    return df_final

# %%
# Función para normalizar por filas con Min-Max, con manejo de casos especiales
def normalize_min_max_by_row(df):
    min_by_row = df.min(axis=1)
    max_by_row = df.max(axis=1)
    # Diferencia entre máximos y mínimos
    range_by_row = max_by_row - min_by_row
    # Evitar división por cero asignando NaN, que luego reemplazaremos
    normalized = (df.sub(min_by_row, axis=0)).div(range_by_row, axis=0)
    # Manejar filas donde max == min (rango es cero), puedes ajustar este valor
    normalized[range_by_row == 0] = 0  # O cualquier otro valor que consideres apropiado
    return normalized

import ast
# Función para convertir string a lista
def string_to_list(string):
    return ast.literal_eval(string)

def plot_confusion_matrix(y_test, y_pred, labels, display_labels, title):
    """
    Función para calcular y mostrar la matriz de confusión con etiquetas descriptivas y un título personalizado.

    Parámetros:
    - y_test: Array con los valores reales.
    - y_pred: Array con las predicciones del modelo.
    - labels: Lista de las etiquetas de clase en el orden en que deben ser tratadas.
    - display_labels: Lista con los nombres descriptivos para las etiquetas de las clases para visualización.
    - title: String con el título para el gráfico de la matriz de confusión.
    """

    # Calcula la matriz de confusión con las etiquetas descriptivas
    cm = confusion_matrix(y_test, y_pred, labels=labels, normalize='true')

    # Crea el display de la matriz de confusión con etiquetas descriptivas
    fig, ax = plt.subplots(figsize=(8, 8))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=display_labels)
    disp.plot(values_format=".0%", colorbar=True, ax=ax)
    disp.im_.colorbar.remove()  # Remueve la barra de color automática para reemplazarla
    disp.im_.set_clim(0, 1)  # Asegura que los límites de la barra de colores sean de 0 a 1

    # Crea manualmente la barra de colores con los límites correctos
    cbar = fig.colorbar(disp.im_, ax=ax)
    cbar.ax.yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1))  # Corrige el formateador para mostrar en porcentajes

    # Ajustes de formato y título
    plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.1)
    plt.title(title, fontsize=20)

    plt.show()

# %% [markdown]
# ## load data

# %%
import pandas as pd

contamination_files = [
    'stellar_contamination/TRAPPIST-1_contam_fspot0.01_ffac0.08.txt',
    'stellar_contamination/TRAPPIST-1_contam_fspot0.01_ffac0.54.txt',
    'stellar_contamination/TRAPPIST-1_contam_fspot0.01_ffac0.70.txt',
    'stellar_contamination/TRAPPIST-1_contam_fspot0.08_ffac0.08.txt',
    'stellar_contamination/TRAPPIST-1_contam_fspot0.08_ffac0.54.txt',
    'stellar_contamination/TRAPPIST-1_contam_fspot0.08_ffac0.70.txt',
    'stellar_contamination/TRAPPIST-1_contam_fspot0.26_ffac0.08.txt',
    'stellar_contamination/TRAPPIST-1_contam_fspot0.26_ffac0.54.txt',
    'stellar_contamination/TRAPPIST-1_contam_fspot0.26_ffac0.70.txt'
]

def filtrar_filas(df):
    """
    Filtra las filas de un DataFrame donde al menos una de las columnas
    "atm CH4", "atm O3" o "atm H2O" tenga un valor mayor o igual a -8.

    Si ninguna de estas columnas está presente, devuelve el DataFrame sin cambios.
    """
    columnas_a_filtrar = ["atm CH4", "atm O3", "atm H2O"]
    columnas_presentes = [col for col in columnas_a_filtrar if col in df.columns]

    for chem in columnas_presentes:

        df = df[df[chem]>=-8]

        # Definir atributos .data y .params en el DataFrame final
        df.data = df.iloc[:, -n_points:]
        df.params = df.iloc[:, :-n_points]

    return df

# Procesamiento de los diferentes datasets

try:
    airless_data = pd.read_csv("spec_data/airless_data.csv")
    airless_data = apply_contaminations_from_files(contamination_files, airless_data, n_points)
except Exception as e:
    print(f"Error al procesar airless_data: {e}")

try:
    CO2_data = pd.read_csv("spec_data/CO2_data.csv")
    CO2_data = apply_contaminations_from_files(contamination_files, CO2_data, n_points)
except Exception as e:
    print(f"Error al procesar CO2_data: {e}")

try:
    CH4_data = pd.read_csv("spec_data/CH4_data.csv")
    CH4_data = filtrar_filas(CH4_data)  # Aplicar el filtrado
    CH4_data = apply_contaminations_from_files(contamination_files, CH4_data, n_points)

except Exception as e:
    print(f"Error al procesar CH4_data: {e}")

try:
    O3_data = pd.read_csv("spec_data/O3_data.csv")
    O3_data = filtrar_filas(O3_data)  # Aplicar el filtrado
    O3_data = apply_contaminations_from_files(contamination_files, O3_data, n_points)

except Exception as e:
    print(f"Error al procesar O3_data: {e}")

try:
    H2O_data = pd.read_csv("spec_data/H2O_data.csv")
    H2O_data = filtrar_filas(H2O_data)  # Aplicar el filtrado
    H2O_data = apply_contaminations_from_files(contamination_files, H2O_data, n_points)

except Exception as e:
    print(f"Error al procesar H2O_data: {e}")

try:
    CH4_O3_data = pd.read_csv("spec_data/CH4_O3_data.csv")
    CH4_O3_data = filtrar_filas(CH4_O3_data)  # Aplicar el filtrado
    CH4_O3_data = apply_contaminations_from_files(contamination_files, CH4_O3_data, n_points)

except Exception as e:
    print(f"Error al procesar CH4_O3_data: {e}")

try:
    CH4_H2O_data = pd.read_csv("spec_data/CH4_H2O_data.csv")
    CH4_H2O_data = filtrar_filas(CH4_H2O_data)  # Aplicar el filtrado
    CH4_H2O_data = apply_contaminations_from_files(contamination_files, CH4_H2O_data, n_points)

except Exception as e:
    print(f"Error al procesar CH4_H2O_data: {e}")

try:
    O3_H2O_data = pd.read_csv("spec_data/O3_H2O_data.csv")
    O3_H2O_data = filtrar_filas(O3_H2O_data)  # Aplicar el filtrado
    O3_H2O_data = apply_contaminations_from_files(contamination_files, O3_H2O_data, n_points)

except Exception as e:
    print(f"Error al procesar O3_H2O_data: {e}")

try:
    CH4_O3_H2O_data = pd.read_csv("spec_data/CH4_O3_H2O_data.csv")
    CH4_O3_H2O_data = filtrar_filas(CH4_O3_H2O_data)  # Aplicar el filtrado
    CH4_O3_H2O_data = apply_contaminations_from_files(contamination_files, CH4_O3_H2O_data, n_points)

except Exception as e:
    print(f"Error al procesar CH4_O3_H2O_data: {e}")
# Out:
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:94: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df_final.data = df_final.iloc[:, -n_points:]
# /tmp/ipykernel_155894/951796714.py:95: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df_final.params = df_final.iloc[:, :-n_points]
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:94: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df_final.data = df_final.iloc[:, -n_points:]
# /tmp/ipykernel_155894/951796714.py:95: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df_final.params = df_final.iloc[:, :-n_points]
# /tmp/ipykernel_155894/3115410802.py:30: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.data = df.iloc[:, -n_points:]
# /tmp/ipykernel_155894/3115410802.py:31: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.params = df.iloc[:, :-n_points]
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:94: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df_final.data = df_final.iloc[:, -n_points:]
# /tmp/ipykernel_155894/951796714.py:95: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df_final.params = df_final.iloc[:, :-n_points]
# /tmp/ipykernel_155894/3115410802.py:30: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.data = df.iloc[:, -n_points:]
# /tmp/ipykernel_155894/3115410802.py:31: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.params = df.iloc[:, :-n_points]
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:94: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df_final.data = df_final.iloc[:, -n_points:]
# /tmp/ipykernel_155894/951796714.py:95: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df_final.params = df_final.iloc[:, :-n_points]
# /tmp/ipykernel_155894/3115410802.py:30: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.data = df.iloc[:, -n_points:]
# /tmp/ipykernel_155894/3115410802.py:31: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.params = df.iloc[:, :-n_points]
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:94: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df_final.data = df_final.iloc[:, -n_points:]
# /tmp/ipykernel_155894/951796714.py:95: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df_final.params = df_final.iloc[:, :-n_points]
# /tmp/ipykernel_155894/3115410802.py:30: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.data = df.iloc[:, -n_points:]
# /tmp/ipykernel_155894/3115410802.py:31: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.params = df.iloc[:, :-n_points]
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:94: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df_final.data = df_final.iloc[:, -n_points:]
# /tmp/ipykernel_155894/951796714.py:95: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df_final.params = df_final.iloc[:, :-n_points]
# /tmp/ipykernel_155894/3115410802.py:30: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.data = df.iloc[:, -n_points:]
# /tmp/ipykernel_155894/3115410802.py:31: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.params = df.iloc[:, :-n_points]
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:94: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df_final.data = df_final.iloc[:, -n_points:]
# /tmp/ipykernel_155894/951796714.py:95: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df_final.params = df_final.iloc[:, :-n_points]
# /tmp/ipykernel_155894/3115410802.py:30: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.data = df.iloc[:, -n_points:]
# /tmp/ipykernel_155894/3115410802.py:31: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.params = df.iloc[:, :-n_points]
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:94: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df_final.data = df_final.iloc[:, -n_points:]
# /tmp/ipykernel_155894/951796714.py:95: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df_final.params = df_final.iloc[:, :-n_points]
# /tmp/ipykernel_155894/3115410802.py:30: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.data = df.iloc[:, -n_points:]
# /tmp/ipykernel_155894/3115410802.py:31: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.params = df.iloc[:, :-n_points]
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_spot'] = f_spot
# /tmp/ipykernel_155894/951796714.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_contam['f_fac'] = f_fac
# /tmp/ipykernel_155894/951796714.py:94: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df_final.data = df_final.iloc[:, -n_points:]
# /tmp/ipykernel_155894/951796714.py:95: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df_final.params = df_final.iloc[:, :-n_points]

# %% [markdown]
# ## RFs

# %%
import joblib
## load rf per molecule
rf_CH4 = joblib.load("CH4_rf_S.joblib") #Specialized
#rf_CH4 = joblib.load("CH4_RF_C.joblib") # Common
rf_O3 = joblib.load("O3_rf_S.joblib") #Specializaed
#rf_O3 = joblib.load("O3_RF_C.joblib")  #Common
rf_H2O = joblib.load("H2O_rf_S.joblib") #Specialized
#rf_H2O = joblib.load("H2O_RF_C.joblib") #Common

from tensorflow import keras 

encoder = keras.models.load_model("Models/AE_OG.keras") # Common
CH4_encoder = keras.models.load_model("Models/AE_CH4_OG.keras") # Specialized
O3_encoder = keras.models.load_model("Models/AE_O3_OG.keras") # Specialized
H2O_encoder = keras.models.load_model("Models/AE_H2O_OG.keras") # Specialized

# %% [markdown]
# ## Test

# %%
import numpy as np
import pandas as pd
import warnings

def generate_df_with_noise_std(df, n_repeat, noise_std, seed=None):
    """
    Genera un nuevo DataFrame aplicando ruido Gaussiano de desviación estándar especificada
    a los espectros de manera vectorizada y concatena el resultado con otro DataFrame que
    contiene otras columnas de información.

    Parámetros:
    - df: DataFrame con parámetros y espectros. Debe tener atributos 'params' y 'data'.
          Ejemplo: df.params, df.data
    - n_repeat: Número de veces que se replica cada espectro.
    - noise_std: Desviación estándar del ruido a aplicar. Puede ser un número único o una
                 lista/array con una desviación estándar para cada espectro.
    - seed: Semilla para el generador de números aleatorios (opcional).

    Retorna:
    - Nuevo DataFrame con parámetros y espectros con ruido agregado en el mismo formato
      que el DataFrame de entrada. df.params, df.data
    """
    # Verificación de atributos 'params' y 'data' en el DataFrame
    if not hasattr(df, "params"):
        print("Advertencia: No se encontró el atributo 'params' en el DataFrame.")
        df_params = pd.DataFrame()
        if not hasattr(df, "data"):
            print("Advertencia: No se encontró el atributo 'data' en el DataFrame.",
                  "Se considerará que el DataFrame contiene solo datos espectrales.")
            df_spectra = df
    else:
        if not hasattr(df, "data"):
            raise ValueError("El DataFrame debe tener un atributo 'data'.")
        else:
            df_params = df.params
            df_spectra = df.data

    # Validaciones de tipos y valores de los parámetros
    if not isinstance(df_spectra, pd.DataFrame):
        raise ValueError("df_spectra debe ser un pandas DataFrame.")
    if not isinstance(df_params, pd.DataFrame):
        raise ValueError("df_params debe ser un pandas DataFrame.")
    if (not isinstance(n_repeat, int) or n_repeat <= 0):
        raise ValueError("n_repeat debe ser un entero positivo.")
    if isinstance(noise_std, (int, float)):
        if noise_std < 0:
            raise ValueError("noise_std debe ser un número positivo.")
    elif isinstance(noise_std, (list, np.ndarray, pd.Series)):
        if not all(n > 0 for n in noise_std):
            raise ValueError("Todos los valores en noise_std deben ser positivos.")
        if len(noise_std) != len(df_spectra):
            raise ValueError("La longitud de noise_std debe coincidir con el número de espectros en df.")
    else:
        raise ValueError("noise_std debe ser un número positivo o una lista/array de números positivos.")
    if (seed is not None and
        (not isinstance(seed, int) or seed < 0)):
        raise ValueError("seed debe ser un entero no negativo.")

    # Configuración de la semilla para reproducibilidad
    if seed is not None:
        np.random.seed(seed)  

    # Replicación del DataFrame de espectros según el factor de repetición
    df_spectra_replicated = pd.DataFrame(
        np.repeat(df_spectra.values, n_repeat, axis=0),
        columns=df_spectra.columns
    )

    # Manejo de noise_std: si es escalar, se expande; si es array, se replica según n_repeat
    if isinstance(noise_std, (int, float)):
        noise_replicated = np.full(df_spectra_replicated.shape, noise_std)
    else:
        noise_array = np.array(noise_std)
        noise_replicated = np.repeat(noise_array[:, np.newaxis], n_repeat, axis=0)
        noise_replicated = np.tile(noise_replicated, (1, df_spectra_replicated.shape[1]))

    # Aplicación vectorizada del ruido Gaussiano
    gaussian_noise = np.random.normal(0, noise_replicated, df_spectra_replicated.shape)
    df_spectra_replicated += gaussian_noise

    # Replicación del DataFrame de parámetros para que coincida con el número de filas de los espectros replicados
    df_other_columns_replicated = pd.DataFrame(
        np.repeat(df_params.values, n_repeat, axis=0),
        columns=df_params.columns
    )

    # Inserción de la columna 'noise' y 'noise_std' en los parámetros replicados
    if isinstance(noise_std, (int, float)):
        df_other_columns_replicated.insert(0, 'noise_std', noise_std)
    else:
        df_other_columns_replicated.insert(0, 'noise_std', np.repeat(noise_std, n_repeat))
    df_other_columns_replicated.insert(1, 'n_repeat', n_repeat)

    # Concatenación de parámetros y espectros ruidosos
    df_final = pd.concat(
        [df_other_columns_replicated.reset_index(drop=True),
         df_spectra_replicated.reset_index(drop=True)],
        axis=1
    )

    # Asignación de atributos 'data' y 'params' al DataFrame final
    warnings.filterwarnings("ignore")
    df_final.data = df_final.iloc[:, -df_spectra_replicated.shape[1]:]
    df_final.params = df_final.iloc[:, :df_other_columns_replicated.shape[1]]
    warnings.filterwarnings("default")
    
    return df_final

# %% [markdown]
# ## Validate per SNR

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.colors as mcolors
from tqdm import tqdm
import pickle
import gc
from sklearn.metrics import (
    f1_score,
    recall_score,
    precision_score,
    accuracy_score,
    hamming_loss,
    confusion_matrix,
    classification_report,
)
from sklearn.metrics import ConfusionMatrixDisplay

# Defined parameters
SNRS = [1, 2, 3, 4, 5, 7, 10]
f_spot_values = [0, 0.01, 0.08, 0.26]  # Includes base case (0)
f_fac_values = [0, 0.08, 0.54, 0.70]   # Includes base case (0)
mix_ratios = np.logspace(-8, -1, 8)

# Base case
base_f_spot = 0
base_f_fac = 0

def filter_data(df, f_spot_val, f_fac_val):
    """Filter DataFrame rows by f_spot and f_fac values."""
    return df[(df["f_spot"] == f_spot_val) & (df["f_fac"] == f_fac_val)]

all_results = {}
factor = 10 / 8
total_combinations = len(f_spot_values) * len(f_fac_values)

# Process each (f_spot, f_fac) combination
with tqdm(total=total_combinations, desc="Processing all f_spot and f_fac combinations") as pbar:
    for f_spot_val in f_spot_values:
        for f_fac_val in f_fac_values:
            # Skip combinations where one is 0 and the other is not (except (0,0))
            if (f_spot_val == 0 and f_fac_val != 0) or (f_spot_val != 0 and f_fac_val == 0):
                pbar.update(1)
                continue

            mol_SNR_scores = {
                "SNR": [],
                "f1": [[], [], []],
                "recall_score": [[], [], []],
                "precision_score": [[], [], []],
                "accuracy": [[], [], []],
                "min_mix_ratio": [[], [], []],
                "TNR": [[], [], []],
            }
            global_SNR_scores = {
                "SNR": [],
                "f1": [],
                "recall": [],
                "precision": [],
                "perfect_match": [],
                "hamming_loss": [],
                "TNR": [],
                "biosignature_recall": [],
            }

            for SNR in tqdm(SNRS, desc=f"f_spot={f_spot_val}, f_fac={f_fac_val}", leave=False):
                # Generate noise for current SNR
                noise = mrex.generate_df_SNR_noise(
                    df=CO2_data,
                    n_repeat=1,
                    SNR=SNR,
                )["noise"][1]

                # Generate noisy data for each dataset
                SNR_test_CO2_data = generate_df_with_noise_std(
                    df=CO2_data,
                    n_repeat=int(2500),
                    noise_std=noise,
                )
                SNR_test_CH4_data = generate_df_with_noise_std(
                    df=CH4_data,
                    n_repeat=int(250 * factor),
                    noise_std=noise,
                )
                SNR_test_O3_data = generate_df_with_noise_std(
                    df=O3_data,
                    n_repeat=int(250 * factor),
                    noise_std=noise,
                )
                SNR_test_H2O_data = generate_df_with_noise_std(
                    df=H2O_data,
                    n_repeat=int(250 * factor),
                    noise_std=noise,
                )
                SNR_test_CH4_O3_data = generate_df_with_noise_std(
                    df=CH4_O3_data,
                    n_repeat=int(25 * factor * factor),
                    noise_std=noise,
                )
                SNR_test_CH4_H2O_data = generate_df_with_noise_std(
                    df=CH4_H2O_data,
                    n_repeat=int(25 * factor * factor),
                    noise_std=noise,
                )
                SNR_test_O3_H2O_data = generate_df_with_noise_std(
                    df=O3_H2O_data,
                    n_repeat=int(25 * factor * factor),
                    noise_std=noise,
                )
                SNR_test_CH4_O3_H2O_data = generate_df_with_noise_std(
                    df=CH4_O3_H2O_data,
                    n_repeat=int(5 * factor * factor * factor),
                    noise_std=noise,
                )
                SNR_test_airless_data = generate_df_with_noise_std(
                    df=airless_data,
                    n_repeat=2_500 * 3,
                    noise_std=noise,
                )

                # Concatenate all DataFrames
                SNR_test_df = pd.concat(
                    [
                        SNR_test_CO2_data,
                        SNR_test_CH4_data,
                        SNR_test_O3_data,
                        SNR_test_H2O_data,
                        SNR_test_CH4_O3_data,
                        SNR_test_CH4_H2O_data,
                        SNR_test_O3_H2O_data,
                        SNR_test_CH4_O3_H2O_data,
                        SNR_test_airless_data,
                    ],
                    ignore_index=True,
                )

                # Free memory
                del (
                    SNR_test_CO2_data,
                    SNR_test_CH4_data,
                    SNR_test_O3_data,
                    SNR_test_H2O_data,
                    SNR_test_CH4_O3_data,
                    SNR_test_CH4_H2O_data,
                    SNR_test_O3_H2O_data,
                    SNR_test_CH4_O3_H2O_data,
                    SNR_test_airless_data,
                )
                gc.collect()

                # Filter data for current (f_spot, f_fac)
                SNR_test_df = filter_data(SNR_test_df, f_spot_val, f_fac_val)
                if SNR_test_df.empty:
                    continue

                # Preprocess data for prediction
                SNR_test_df["label"] = SNR_test_df["label"].apply(string_to_list)
                SNR_test_df.iloc[:, -n_points:] = normalize_min_max_by_row(
                    SNR_test_df.iloc[:, -n_points:]
                )
                SNR_X_test = SNR_test_df.iloc[:, -n_points:]
                # For common strategy use: SNR_X_test = encoder.predict(SNR_X_test)
                # For specialized strategy, use specialized autoencoders:
                SNR_X_test_CH4 = CH4_encoder.predict(SNR_X_test)
                SNR_X_test_O3 = O3_encoder.predict(SNR_X_test)
                SNR_X_test_H2O = H2O_encoder.predict(SNR_X_test)

                # Extract true labels
                SNR_test_CH4 = np.array([item[0] for item in SNR_test_df["label"]])
                SNR_test_O3 = np.array([item[1] for item in SNR_test_df["label"]])
                SNR_test_H2O = np.array([item[2] for item in SNR_test_df["label"]])
                SNR_test_df["CH4 label"] = SNR_test_CH4
                SNR_test_df["O3 label"] = SNR_test_O3
                SNR_test_df["H2O label"] = SNR_test_H2O

                # Use specialized RF models (uncomment the below block for common RF models)
                # CH4_probabilities = rf_CH4.predict_proba(SNR_X_test)[:, 1]
                # O3_probabilities = rf_O3.predict_proba(SNR_X_test)[:, 1]
                # H2O_probabilities = rf_H2O.predict_proba(SNR_X_test)[:, 1]
                CH4_probabilities = rf_CH4.predict_proba(SNR_X_test_CH4)[:, 1]
                O3_probabilities = rf_O3.predict_proba(SNR_X_test_O3)[:, 1]
                H2O_probabilities = rf_H2O.predict_proba(SNR_X_test_H2O)[:, 1]

                # Set thresholds based on strategy type.
                # Specialized strategy uses three autoencoders and RF models.
                # Common strategy uses a single autoencoder and RF.
                strategy = "specialized"  # Set to "common" if using common models
                if strategy == "specialized":
                    CH4_threshold = 0.33
                    O3_threshold = 0.27
                    H2O_threshold = 0.43
                else:
                    CH4_threshold = 0.32
                    O3_threshold = 0.24
                    H2O_threshold = 0.37

                CH4_y_pred = (CH4_probabilities > CH4_threshold).astype(int)
                O3_y_pred = (O3_probabilities > O3_threshold).astype(int)
                H2O_y_pred = (H2O_probabilities > H2O_threshold).astype(int)

                SNR_test_df["CH4 pred"] = CH4_y_pred
                SNR_test_df["CH4 score"] = CH4_probabilities
                SNR_test_df["O3 pred"] = O3_y_pred
                SNR_test_df["O3 score"] = O3_probabilities
                SNR_test_df["H2O pred"] = H2O_y_pred
                SNR_test_df["H2O score"] = H2O_probabilities

                # Calculate global metrics
                global_SNR_scores["SNR"].append(SNR)
                global_SNR_scores["f1"].append(
                    f1_score(
                        SNR_test_df[["CH4 label", "O3 label", "H2O label"]],
                        SNR_test_df[["CH4 pred", "O3 pred", "H2O pred"]],
                        average="macro",
                    )
                )
                global_SNR_scores["recall"].append(
                    recall_score(
                        SNR_test_df[["CH4 label", "O3 label", "H2O label"]],
                        SNR_test_df[["CH4 pred", "O3 pred", "H2O pred"]],
                        average="macro",
                    )
                )
                global_SNR_scores["precision"].append(
                    precision_score(
                        SNR_test_df[["CH4 label", "O3 label", "H2O label"]],
                        SNR_test_df[["CH4 pred", "O3 pred", "H2O pred"]],
                        average="macro",
                    )
                )
                global_SNR_scores["perfect_match"].append(
                    accuracy_score(
                        SNR_test_df[["CH4 label", "O3 label", "H2O label"]],
                        SNR_test_df[["CH4 pred", "O3 pred", "H2O pred"]],
                    )
                )
                global_SNR_scores["hamming_loss"].append(
                    hamming_loss(
                        SNR_test_df[["CH4 label", "O3 label", "H2O label"]],
                        SNR_test_df[["CH4 pred", "O3 pred", "H2O pred"]],
                    )
                )

                both_CH4_O3_label = (
                    (SNR_test_df["CH4 label"] == 1) & (SNR_test_df["O3 label"] == 1)
                ).astype(int)
                both_CH4_O3_pred = (
                    (SNR_test_df["CH4 pred"] == 1) & (SNR_test_df["O3 pred"] == 1)
                ).astype(int)
                biosig_rec = recall_score(both_CH4_O3_label, both_CH4_O3_pred)
                global_SNR_scores["biosignature_recall"].append(biosig_rec)

                # Calculate molecule-specific metrics
                mol_SNR_scores["SNR"].append(SNR)
                mol_SNR_scores["f1"][0].append(f1_score(SNR_test_df["CH4 label"], SNR_test_df["CH4 pred"]))
                mol_SNR_scores["f1"][1].append(f1_score(SNR_test_df["O3 label"], SNR_test_df["O3 pred"]))
                mol_SNR_scores["f1"][2].append(f1_score(SNR_test_df["H2O label"], SNR_test_df["H2O pred"]))

                mol_SNR_scores["recall_score"][0].append(
                    recall_score(SNR_test_df["CH4 label"], SNR_test_df["CH4 pred"])
                )
                mol_SNR_scores["recall_score"][1].append(
                    recall_score(SNR_test_df["O3 label"], SNR_test_df["O3 pred"])
                )
                mol_SNR_scores["recall_score"][2].append(
                    recall_score(SNR_test_df["H2O label"], SNR_test_df["H2O pred"])
                )

                mol_SNR_scores["precision_score"][0].append(
                    precision_score(SNR_test_df["CH4 label"], SNR_test_df["CH4 pred"])
                )
                mol_SNR_scores["precision_score"][1].append(
                    precision_score(SNR_test_df["O3 label"], SNR_test_df["O3 pred"])
                )
                mol_SNR_scores["precision_score"][2].append(
                    precision_score(SNR_test_df["H2O label"], SNR_test_df["H2O pred"])
                )

                mol_SNR_scores["accuracy"][0].append(
                    accuracy_score(SNR_test_df["CH4 label"], SNR_test_df["CH4 pred"])
                )
                mol_SNR_scores["accuracy"][1].append(
                    accuracy_score(SNR_test_df["O3 label"], SNR_test_df["O3 pred"])
                )
                mol_SNR_scores["accuracy"][2].append(
                    accuracy_score(SNR_test_df["H2O label"], SNR_test_df["H2O pred"])
                )

                mol_SNR_scores["TNR"][0].append(
                    recall_score(SNR_test_df["CH4 label"], SNR_test_df["CH4 pred"], pos_label=0)
                )
                mol_SNR_scores["TNR"][1].append(
                    recall_score(SNR_test_df["O3 label"], SNR_test_df["O3 pred"], pos_label=0)
                )
                mol_SNR_scores["TNR"][2].append(
                    recall_score(SNR_test_df["H2O label"], SNR_test_df["H2O pred"], pos_label=0)
                )

                global_SNR_scores["TNR"].append(
                    (mol_SNR_scores["TNR"][0][-1] + mol_SNR_scores["TNR"][1][-1] + mol_SNR_scores["TNR"][2][-1])
                    / 3
                )

                # Calculate min_mix_ratio per molecule based on recall threshold > 0.6
                CH4_SNR_test_by_atmCH4 = [[] for _ in range(8)]
                O3_SNR_test_by_atmO3 = [[] for _ in range(8)]
                H2O_SNR_test_by_atmH2O = [[] for _ in range(8)]

                for idx, atm_val in enumerate(range(-8, 0)):
                    CH4_group = SNR_test_df[SNR_test_df["atm CH4"] == atm_val]
                    co2 = int(len(SNR_test_df[SNR_test_df["CH4 label"] == 0]) / 8)
                    no_CH4 = SNR_test_df[SNR_test_df["CH4 label"] == 0].sample(co2)
                    CH4_SNR_test_by_atmCH4[idx] = pd.concat([CH4_group, no_CH4])

                    O3_group = SNR_test_df[SNR_test_df["atm O3"] == atm_val]
                    co2 = int(len(SNR_test_df[SNR_test_df["O3 label"] == 0]) / 8)
                    no_O3 = SNR_test_df[SNR_test_df["O3 label"] == 0].sample(co2)
                    O3_SNR_test_by_atmO3[idx] = pd.concat([O3_group, no_O3])

                    H2O_group = SNR_test_df[SNR_test_df["atm H2O"] == atm_val]
                    co2 = int(len(SNR_test_df[SNR_test_df["H2O label"] == 0]) / 8)
                    no_H2O = SNR_test_df[SNR_test_df["H2O label"] == 0].sample(co2)
                    H2O_SNR_test_by_atmH2O[idx] = pd.concat([H2O_group, no_H2O])

                CH4_SNR_recall = np.zeros(len(mix_ratios))
                O3_SNR_recall = np.zeros(len(mix_ratios))
                H2O_SNR_recall = np.zeros(len(mix_ratios))

                for m_idx in range(len(mix_ratios)):
                    CH4_labels = CH4_SNR_test_by_atmCH4[m_idx]["CH4 label"].astype(int)
                    CH4_preds = CH4_SNR_test_by_atmCH4[m_idx]["CH4 pred"].astype(int)
                    CH4_SNR_recall[m_idx] = recall_score(CH4_labels, CH4_preds)

                    O3_labels = O3_SNR_test_by_atmO3[m_idx]["O3 label"].astype(int)
                    O3_preds = O3_SNR_test_by_atmO3[m_idx]["O3 pred"].astype(int)
                    O3_SNR_recall[m_idx] = recall_score(O3_labels, O3_preds)

                    H2O_labels = H2O_SNR_test_by_atmH2O[m_idx]["H2O label"].astype(int)
                    H2O_preds = H2O_SNR_test_by_atmH2O[m_idx]["H2O pred"].astype(int)
                    H2O_SNR_recall[m_idx] = recall_score(H2O_labels, H2O_preds)

                CH4_min_mix_ratio = (
                    mix_ratios[np.where(CH4_SNR_recall >= 0.6)][0]
                    if np.any(CH4_SNR_recall >= 0.6)
                    else 1
                )
                O3_min_mix_ratio = (
                    mix_ratios[np.where(O3_SNR_recall >= 0.6)][0]
                    if np.any(O3_SNR_recall >= 0.6)
                    else 1
                )
                H2O_min_mix_ratio = (
                    mix_ratios[np.where(H2O_SNR_recall >= 0.6)][0]
                    if np.any(H2O_SNR_recall >= 0.6)
                    else 1
                )

                mol_SNR_scores["min_mix_ratio"][0].append(CH4_min_mix_ratio)
                mol_SNR_scores["min_mix_ratio"][1].append(O3_min_mix_ratio)
                mol_SNR_scores["min_mix_ratio"][2].append(H2O_min_mix_ratio)

            all_results[(f_spot_val, f_fac_val)] = {
                "global_SNR_scores": global_SNR_scores,
                "mol_SNR_scores": mol_SNR_scores,
            }
            pbar.update(1)
# Out:
# Processing all f_spot and f_fac combinations:   0%|          | 0/16 [00:00<?, ?it/s]
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 972us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 951us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 910us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 951us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 963us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 917us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 919us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 940us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 898us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 988us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 951us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 940us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 980us/step
# Processing all f_spot and f_fac combinations:   6%|▋         | 1/16 [04:54<1:13:43, 294.88s/it]
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 944us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 939us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 930us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 935us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 928us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 913us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 977us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 842us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 786us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 767us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 844us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 773us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 758us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 964us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 941us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 883us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 842us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 894us/step
# Processing all f_spot and f_fac combinations:  38%|███▊      | 6/16 [09:10<13:30, 81.08s/it]
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 817us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 796us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 774us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 786us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 774us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 851us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 914us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 981us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 786us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 785us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 783us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 777us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 779us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 798us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 806us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 798us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 775us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 808us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 782us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 818us/step
# Processing all f_spot and f_fac combinations:  44%|████▍     | 7/16 [12:18<15:22, 102.51s/it]
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 864us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 779us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 801us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 932us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 896us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 921us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 842us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 924us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 823us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 785us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 767us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 793us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 780us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 776us/step
# Processing all f_spot and f_fac combinations:  50%|█████     | 8/16 [16:00<17:13, 129.18s/it]
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 767us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 844us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 931us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 799us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 826us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 780us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 833us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 769us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 765us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 974us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 901us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 824us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 878us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 946us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 924us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 784us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 783us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 814us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 798us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 782us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 907us/step
# Processing all f_spot and f_fac combinations:  62%|██████▎   | 10/16 [19:23<11:49, 118.23s/it]
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 963us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 967us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 877us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 852us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 976us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 995us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 941us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 878us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 866us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 790us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 860us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 806us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 992us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 966us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 929us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 955us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 944us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 928us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 814us/step
# Processing all f_spot and f_fac combinations:  69%|██████▉   | 11/16 [22:56<11:34, 138.86s/it]
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 763us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 770us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 932us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 783us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 805us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 812us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 894us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 993us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 832us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 770us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 858us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 885us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 816us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 790us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 765us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 775us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 787us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 955us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 879us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 812us/step
# Processing all f_spot and f_fac combinations:  75%|███████▌  | 12/16 [26:19<10:16, 154.08s/it]
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 966us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 810us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 806us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 830us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 762us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 898us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 917us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 771us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 843us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 798us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 796us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 965us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 973us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 850us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 903us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 935us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 860us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 874us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 773us/step
# Processing all f_spot and f_fac combinations:  88%|████████▊ | 14/16 [29:55<04:31, 135.51s/it]
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 905us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 864us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 824us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 773us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 877us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 783us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 996us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 911us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 980us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 824us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 763us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 764us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 777us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 770us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 762us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 840us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 798us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 840us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 779us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 835us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 859us/step
# Processing all f_spot and f_fac combinations:  94%|█████████▍| 15/16 [33:07<02:28, 148.19s/it]
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 854us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 984us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 872us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 917us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 765us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 790us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 836us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 876us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 870us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 782us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 764us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 859us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 782us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 912us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 824us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 854us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 813us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 953us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 877us/step
# 2305/2305 ━━━━━━━━━━━━━━━━━━━━ 2s 960us/step
# Processing all f_spot and f_fac combinations: 100%|██████████| 16/16 [37:00<00:00, 138.79s/it]

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.colors as mcolors
from collections import OrderedDict

# Base parameters
base_f_spot = 0
base_f_fac = 0

# SNR and mixing ratio vectors
SNRS = [1, 2, 3, 4, 5, 7, 10]
mix_ratios = np.logspace(-8, -1, 8)

# Extract base case results
base_global_scores = all_results[(base_f_spot, base_f_fac)]["global_SNR_scores"]
base_mol_scores = all_results[(base_f_spot, base_f_fac)]["mol_SNR_scores"]

# 2) AUXILIARY FUNCTIONS
def adjust_color_lightness(color, amount=0.7):
    """Adjusts the lightness of a color."""
    try:
        c = mcolors.to_rgb(color)
    except ValueError:
        c = (0.5, 0.5, 0.5)
    return [min(1, max(0, channel * amount)) for channel in c]


# Convert hamming_loss to 1 - hamming_loss for the base case
base_global_scores["1_hamming_loss"] = 1 - np.array(base_global_scores["hamming_loss"])

# 3) STYLE CONFIGURATION AND METRICS DICTIONARIES
global_metrics_colors = {
    "f1": "#1f77b4",
    "recall": "#ff7f0e",
    "precision": "#2ca02c",
    "perfect_match": "#d62728",
    "1_hamming_loss": "#9467bd",
    "TNR": "#8c564b",
    "biosignature_recall": "#180118",  # NEW
}
global_metrics_markers = {
    "f1": "o",
    "recall": ".",
    "precision": "*",
    "perfect_match": "x",
    "1_hamming_loss": "s",
    "TNR": "^",
    "biosignature_recall": "v",  # NEW
}
global_titles = {
    "f1": "F1 Score",
    "recall": "Recall",
    "precision": "Precision",
    "perfect_match": "Perfect Match",
    "1_hamming_loss": "1 - Hamming Loss",
    "TNR": "TNR",
    "biosignature_recall": "Biosignature Recall (CH4 & O3)",
}
global_metrics = [
    "f1",
    "recall",
    "precision",
    "perfect_match",
    "1_hamming_loss",
    "TNR",
    "biosignature_recall",  # NEW
]

# Molecule-specific settings
ch4_base_color = "#B7950B"
o3_base_color = "#B03A2E"
h2o_base_color = "#2874A6"
molecules_colors = [ch4_base_color, o3_base_color, h2o_base_color]
molecules_labels = ["$CH_4$", "$O_3$", "$H_2O$"]
mol_metrics_markers = {
    "f1": "o",
    "recall_score": ".",
    "precision_score": "*",
    "TNR": "^",
}

available_mol_keys = base_mol_scores.keys()
print("Available keys in mol_SNR_scores for the base case:", available_mol_keys)

if "recall_score" in available_mol_keys:
    metrics_keys_mol = ["f1", "recall_score", "precision_score", "TNR"]
    metrics_titles_mol = ["F1 Score", "Recall", "Precision", "TNR"]
elif "recall" in available_mol_keys:
    metrics_keys_mol = ["f1", "recall", "precision_score", "TNR"]
    metrics_titles_mol = ["F1 Score", "Recall", "Precision", "TNR"]
else:
    raise KeyError("Neither 'recall_score' nor 'recall' are available in 'mol_SNR_scores'.")

# 4) FUNCTIONS TO GET MIN/MAX VALUES (for fill_between)
def get_min_max_global(metric, snrs):
    """
    Calculates min and max for a global metric across all (f_spot, f_fac) combinations
    (excluding the base) and returns arrays for fill_between.
    """
    mins, maxs = [], []
    for snr in snrs:
        values = []
        for (fsp, ffac), results in all_results.items():
            if fsp == base_f_spot and ffac == base_f_fac:
                continue
            if snr in results["global_SNR_scores"]["SNR"]:
                idx = results["global_SNR_scores"]["SNR"].index(snr)
                if metric == "1_hamming_loss":
                    val = 1 - results["global_SNR_scores"]["hamming_loss"][idx]
                else:
                    val = results["global_SNR_scores"][metric][idx]
                values.append(val)
        if values:
            mins.append(min(values))
            maxs.append(max(values))
        else:
            base_val = base_global_scores[metric][base_global_scores["SNR"].index(snr)]
            mins.append(base_val)
            maxs.append(base_val)
    return np.array(mins), np.array(maxs)


def get_min_max_mol(metric, mol_idx, snrs):
    """
    Calculates min and max for a molecule-specific metric across all (f_spot, f_fac) combinations.
    """
    mins, maxs = [], []
    for snr in snrs:
        values = []
        for (fsp, ffac), results in all_results.items():
            if fsp == base_f_spot and ffac == base_f_fac:
                continue
            if snr in results["mol_SNR_scores"]["SNR"]:
                idx = results["mol_SNR_scores"]["SNR"].index(snr)
                val = results["mol_SNR_scores"][metric][mol_idx][idx]
                values.append(val)
        if values:
            mins.append(min(values))
            maxs.append(max(values))
        else:
            base_val = base_mol_scores[metric][mol_idx][base_mol_scores["SNR"].index(snr)]
            mins.append(base_val)
            maxs.append(base_val)
    return np.array(mins), np.array(maxs)


# 5) PLOT GLOBAL METRICS (including new metrics)
plt.figure(figsize=(10, 7))
snrs = base_global_scores["SNR"]

for metric in global_metrics:
    min_vals, max_vals = get_min_max_global(metric, snrs)
    plt.fill_between(snrs, min_vals, max_vals,
                     color=global_metrics_colors[metric], alpha=0.2)
    base_y = base_global_scores["1_hamming_loss"] if metric == "1_hamming_loss" else base_global_scores[metric]
    plt.plot(snrs, base_y,
             marker=global_metrics_markers[metric],
             color=global_metrics_colors[metric],
             linewidth=2,
             label=("Chemical Disequilibrium Recall" if metric == "biosignature_recall"
                    else global_titles[metric]))

plt.fill_between(snrs, 0, 0.6, color="purple", alpha=0.05, hatch="//")
plt.xscale("log")
plt.xlabel("SNR", fontsize=14)
plt.ylabel("Metric Score", fontsize=14)
plt.xticks([1, 2, 3, 4, 5, 7, 10], [str(x) for x in [1, 2, 3, 4, 5, 7, 10]])
plt.xlim(1, 10)
plt.ylim(0, 1)
plt.title("Multilabel Metrics - SC: Common AE", fontsize=18)
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.ScalarFormatter())
ax.xaxis.set_minor_formatter(ticker.NullFormatter())
ax.ticklabel_format(axis="x", style="plain")
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
handles, labels = plt.gca().get_legend_handles_labels()
by_label = OrderedDict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(),
           title="Metrics", title_fontsize=12,
           loc="lower right", fontsize=12)
plt.tight_layout()
#plt.savefig("fotos/auto-SC-mulmetrics.svg", dpi=300)
plt.show()

# 6) PLOT MINIMUM MIXING RATIO (for each molecule)
plt.figure(figsize=(9, 6))
plt.plot(snrs, base_mol_scores["min_mix_ratio"][0], "-o",
         label="$CH_4$", color=ch4_base_color, markersize=8)
plt.plot(snrs, base_mol_scores["min_mix_ratio"][1], "-^",
         label="$O_3$", color=o3_base_color, markersize=8)
plt.plot(snrs, base_mol_scores["min_mix_ratio"][2], "-*",
         label="$H_2O$", color=h2o_base_color, markersize=8)
for mol_idx, _ in enumerate(molecules_labels):
    min_vals, max_vals = get_min_max_mol("min_mix_ratio", mol_idx, snrs)
    plt.fill_between(snrs, min_vals, max_vals,
                     color=molecules_colors[mol_idx], alpha=0.2)
plt.xscale("log")
plt.xlabel("SNR", fontsize=14)
plt.ylabel("Mix Ratio", fontsize=14)
plt.xticks([1, 2, 3, 4, 5, 7, 10], [str(x) for x in [1, 2, 3, 4, 5, 7, 10]])
plt.xlim(1, 10)
plt.yscale("log")
plt.ylim(1e-10, 1)
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.ScalarFormatter())
ax.xaxis.set_minor_formatter(ticker.NullFormatter())
ax.ticklabel_format(axis="x", style="plain")
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
handles, labels = plt.gca().get_legend_handles_labels()
by_label = OrderedDict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(),
           title="Molecules", title_fontsize=12,
           loc="upper left", fontsize=12)
plt.title("Minimum Mixing Ratio for Detection - SC: Common AE", fontsize=18)
plt.tight_layout()
# plt.savefig("fotos/auto-SC-minmix_v2.svg", dpi=300)
plt.show()

# 7) PLOT MOLECULE-SPECIFIC METRICS (f1, recall, precision, TNR) with fill_between
fig_mol, axs_mol = plt.subplots(2, 2, figsize=(10, 10))
axs_mol = axs_mol.flatten()
snrs = base_mol_scores["SNR"]

for i, (m_key, title) in enumerate(zip(metrics_keys_mol, metrics_titles_mol)):
    ax = axs_mol[i]
    for mol_idx, mol_label in enumerate(molecules_labels):
        min_vals, max_vals = get_min_max_mol(m_key, mol_idx, snrs)
        ax.fill_between(snrs, min_vals, max_vals, color=molecules_colors[mol_idx], alpha=0.2)
        ax.plot(snrs, base_mol_scores[m_key][mol_idx],
                marker=mol_metrics_markers[m_key],
                color=molecules_colors[mol_idx],
                linewidth=2,
                label=mol_label)
    ax.fill_between(snrs, 0, 0.6, color="purple", alpha=0.05, hatch="//")
    ax.set_xscale("log")
    ax.set_xlabel("SNR", fontsize=14)
    ax.set_ylabel("Metric Score", fontsize=14)
    ax.set_title(title, fontsize=18)
    ax.set_xticks(snrs)
    ax.xaxis.set_major_formatter(ticker.ScalarFormatter())
    ax.xaxis.set_minor_formatter(ticker.NullFormatter())
    ax.set_xlim(1, 10)
    ax.set_ylim(0, 1)
    ax.ticklabel_format(axis="x", style="plain")
    ax.grid(True, which="both", linestyle="--", linewidth=0.5)
    if i == 0:
        ax.legend(loc="lower right", fontsize=12, title="Molecules", title_fontsize=12)
fig_mol.suptitle("Metrics per Molecule - SC: Common AE", fontsize=18)
fig_mol.tight_layout()
#plt.savefig("fotos/auto-SC-molmetrics.svg", dpi=300)
plt.show()
# Out:
# Available keys in mol_SNR_scores for the base case: dict_keys(['SNR', 'f1', 'recall_score', 'precision_score', 'accuracy', 'min_mix_ratio', 'TNR'])

# %% [markdown]
# ## Validate vs other molecules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.colors as mcolors
from tqdm import tqdm
import pickle
import gc
from sklearn.metrics import (
    f1_score,
    recall_score,
    precision_score,
    accuracy_score,
    hamming_loss,
)
from sklearn.metrics import ConfusionMatrixDisplay

# Uncomment the following line if you use seaborn for heatmaps
# import seaborn as sns

# SNRS can be set to a list; here we choose [3] for testing.
SNRS = [3]

for SNR in SNRS:
    print(f"SNR = {SNR}")

    # Generate noise for the current SNR
    noise = mrex.generate_df_SNR_noise(
        df=CO2_data,
        n_repeat=1,
        SNR=SNR,
    )["noise"][1]

    # Generate noisy datasets for various molecules
    SNR_test_CO2_data = generate_df_with_noise_std(
        df=CO2_data,
        n_repeat=5000,
        noise_std=noise,
    )
    SNR_test_CH4_data = generate_df_with_noise_std(
        df=CH4_data,
        n_repeat=250,
        noise_std=noise,
    )
    SNR_test_O3_data = generate_df_with_noise_std(
        df=O3_data,
        n_repeat=250,
        noise_std=noise,
    )
    SNR_test_H2O_data = generate_df_with_noise_std(
        df=H2O_data,
        n_repeat=250,
        noise_std=noise,
    )
    SNR_test_CH4_O3_data = generate_df_with_noise_std(
        df=CH4_O3_data,
        n_repeat=25,
        noise_std=noise,
    )
    SNR_test_CH4_H2O_data = generate_df_with_noise_std(
        df=CH4_H2O_data,
        n_repeat=25,
        noise_std=noise,
    )
    SNR_test_O3_H2O_data = generate_df_with_noise_std(
        df=O3_H2O_data,
        n_repeat=25,
        noise_std=noise,
    )
    SNR_test_CH4_O3_H2O_data = generate_df_with_noise_std(
        df=CH4_O3_H2O_data,
        n_repeat=5,
        noise_std=noise,
    )
    SNR_test_noatm_data = generate_df_with_noise_std(
        df=airless_data,
        n_repeat=5000,
        noise_std=noise,
    )

    # Concatenate all noisy datasets
    SNR_test_df = pd.concat(
        [
            SNR_test_CO2_data,
            SNR_test_CH4_data,
            SNR_test_O3_data,
            SNR_test_H2O_data,
            SNR_test_CH4_O3_data,
            SNR_test_CH4_H2O_data,
            SNR_test_O3_H2O_data,
            SNR_test_CH4_O3_H2O_data,
            SNR_test_noatm_data,
        ],
        ignore_index=True,
    )

    # Free memory from intermediate DataFrames
    del (
        SNR_test_CO2_data,
        SNR_test_CH4_data,
        SNR_test_O3_data,
        SNR_test_H2O_data,
        SNR_test_CH4_O3_data,
        SNR_test_CH4_H2O_data,
        SNR_test_O3_H2O_data,
        SNR_test_CH4_O3_H2O_data,
        SNR_test_noatm_data,
    )
    gc.collect()

    # Preprocess labels and normalize the spectral data
    SNR_test_df["label"] = SNR_test_df["label"].apply(string_to_list)
    SNR_test_df.iloc[:, -n_points:] = normalize_min_max_by_row(
        SNR_test_df.iloc[:, -n_points:]
    )
    SNR_X_test = SNR_test_df.iloc[:, -n_points:]

    # ==============================
    # Prediction Strategy:
    # For the common strategy (a single autoencoder and RF model), uncomment:
    # SNR_X_test = encoder.predict(SNR_X_test)
    # CH4_probabilities = rf.predict_proba(SNR_X_test)[:, 1]
    # O3_probabilities = rf.predict_proba(SNR_X_test)[:, 1]
    # H2O_probabilities = rf.predict_proba(SNR_X_test)[:, 1]
    #
    # For the specialized strategy (separate autoencoders and RF models), use:
    SNR_X_test_CH4 = CH4_encoder.predict(SNR_X_test)
    SNR_X_test_O3 = O3_encoder.predict(SNR_X_test)
    SNR_X_test_H2O = H2O_encoder.predict(SNR_X_test)
    CH4_probabilities = rf_CH4.predict_proba(SNR_X_test_CH4)[:, 1]
    O3_probabilities = rf_O3.predict_proba(SNR_X_test_O3)[:, 1]
    H2O_probabilities = rf_H2O.predict_proba(SNR_X_test_H2O)[:, 1]
    # ==============================

    # Extract true labels for each molecule
    SNR_test_CH4 = np.array([item[0] for item in SNR_test_df["label"]])
    SNR_test_O3 = np.array([item[1] for item in SNR_test_df["label"]])
    SNR_test_H2O = np.array([item[2] for item in SNR_test_df["label"]])
    SNR_test_df["CH4 label"] = SNR_test_CH4
    SNR_test_df["O3 label"] = SNR_test_O3
    SNR_test_df["H2O label"] = SNR_test_H2O

    # Move the last three columns (labels) to the beginning
    cols = list(SNR_test_df.columns)
    SNR_test_df = SNR_test_df[cols[-3:] + cols[:-3]]

    # Set prediction thresholds; choose based on the strategy.
    # Specialized strategy thresholds:
    #   CH4_threshold = 0.33, O3_threshold = 0.27, H2O_threshold = 0.43
    # Common strategy thresholds:
    #   CH4_threshold = 0.32, O3_threshold = 0.24, H2O_threshold = 0.37
    strategy = "specialized"  # Change to "common" if using the common models
    if strategy == "specialized":
        CH4_threshold = 0.33
        O3_threshold = 0.27
        H2O_threshold = 0.43
    else:
        CH4_threshold = 0.32
        O3_threshold = 0.24
        H2O_threshold = 0.37

    CH4_y_pred = (CH4_probabilities > CH4_threshold).astype(int)
    O3_y_pred = (O3_probabilities > O3_threshold).astype(int)
    H2O_y_pred = (H2O_probabilities > H2O_threshold).astype(int)

    # Assign predictions and scores to the DataFrame
    SNR_test_df["CH4 pred"] = CH4_y_pred
    SNR_test_df["CH4 score"] = CH4_probabilities
    SNR_test_df["O3 pred"] = O3_y_pred
    SNR_test_df["O3 score"] = O3_probabilities
    SNR_test_df["H2O pred"] = H2O_y_pred
    SNR_test_df["H2O score"] = H2O_probabilities

    # Calculate interference metrics (accuracy scores) for each mixing ratio combination
    si_CH4_sO3 = np.zeros((8, 8))
    si_CH4_sH2O = np.zeros((8, 8))
    si_O3_sCH4 = np.zeros((8, 8))
    si_O3_sH2O = np.zeros((8, 8))
    si_H2O_sCH4 = np.zeros((8, 8))
    si_H2O_sO3 = np.zeros((8, 8))

    for i, mix1 in enumerate(range(-8, 0)):
        for j, mix2 in enumerate(range(-8, 0)):
            permix_si_CH4_sO3 = SNR_test_df[
                (SNR_test_df["atm O3"] == mix2) & (SNR_test_df["atm CH4"] == mix1)
            ]
            permix_si_CH4_sH2O = SNR_test_df[
                (SNR_test_df["atm H2O"] == mix2) & (SNR_test_df["atm CH4"] == mix1)
            ]
            permix_si_O3_sCH4 = SNR_test_df[
                (SNR_test_df["atm CH4"] == mix2) & (SNR_test_df["atm O3"] == mix1)
            ]
            permix_si_O3_sH2O = SNR_test_df[
                (SNR_test_df["atm H2O"] == mix2) & (SNR_test_df["atm O3"] == mix1)
            ]
            permix_si_H2O_sCH4 = SNR_test_df[
                (SNR_test_df["atm CH4"] == mix2) & (SNR_test_df["atm H2O"] == mix1)
            ]
            permix_si_H2O_sO3 = SNR_test_df[
                (SNR_test_df["atm O3"] == mix2) & (SNR_test_df["atm H2O"] == mix1)
            ]
            si_CH4_sO3[i, j] = accuracy_score(permix_si_CH4_sO3["CH4 label"], permix_si_CH4_sO3["CH4 pred"])
            si_CH4_sH2O[i, j] = accuracy_score(permix_si_CH4_sH2O["CH4 label"], permix_si_CH4_sH2O["CH4 pred"])
            si_O3_sCH4[i, j] = accuracy_score(permix_si_O3_sCH4["O3 label"], permix_si_O3_sCH4["O3 pred"])
            si_O3_sH2O[i, j] = accuracy_score(permix_si_O3_sH2O["O3 label"], permix_si_O3_sH2O["O3 pred"])
            si_H2O_sCH4[i, j] = accuracy_score(permix_si_H2O_sCH4["H2O label"], permix_si_H2O_sCH4["H2O pred"])
            si_H2O_sO3[i, j] = accuracy_score(permix_si_H2O_sO3["H2O label"], permix_si_H2O_sO3["H2O pred"])

    # Define mixing ratio range for plotting
    log_ratios = np.arange(-8, 0, 1)

    # Define custom colormaps for each gas
    from matplotlib.colors import LinearSegmentedColormap
    color_scales = {
        "CH4": ["#7E5109", "#B7950B", "#F1C40F", "#F4D03F", "#F9E79F", "#FEF9E7"],
        "O3": ["#641E16", "#B03A2E", "#E74C3C", "#EC7063", "#F5B7B1", "#FDEDEC"],
        "H2O": ["#154360", "#1F618D", "#2471A3", "#5499C7", "#A9CCE3", "#EAF2F8"],
    }
    color_ch4 = LinearSegmentedColormap.from_list("CH4", color_scales["CH4"], N=256)
    color_o3 = LinearSegmentedColormap.from_list("O3", color_scales["O3"], N=256)
    color_h2o = LinearSegmentedColormap.from_list("H2O", color_scales["H2O"], N=256)

    # Create subplots using GridSpec for heatmaps
    fig = plt.figure(figsize=(15, 21))
    gs = fig.add_gridspec(3, 3, width_ratios=[1, 1, 0.05], wspace=0.05)

    def add_label(ax, text):
        ax.annotate(
            text,
            xy=(0.25, 0.9),
            xycoords="axes fraction",
            fontsize=14,
            ha="center",
            bbox=dict(facecolor="white", alpha=0.5),
        )

    # Heatmap 1: CH4 Recall with O3 interference
    ax1 = fig.add_subplot(gs[0, 0])
    sns.heatmap(
        si_CH4_sO3,
        ax=ax1,
        vmin=0,
        vmax=1,
        xticklabels=log_ratios,
        yticklabels=log_ratios,
        cmap=color_ch4,
        cbar=False,
    )
    ax1.set_title("CH$_4$ Recall with O$_3$ interference")
    ax1.set_xlabel("$log_{10}$(Mixing Ratio of $O_3$)")
    ax1.set_ylabel("$log_{10}$(Mixing Ratio of $CH_4$)")
    ax1.invert_yaxis()
    add_label(ax1, "Interference by $O_3$")

    # Heatmap 2: CH4 Recall with H2O interference
    ax2 = fig.add_subplot(gs[0, 1], sharey=ax1)
    cbar_ax1 = fig.add_subplot(gs[0, 2])
    sns.heatmap(
        si_CH4_sH2O,
        ax=ax2,
        vmin=0,
        vmax=1,
        xticklabels=log_ratios,
        yticklabels=log_ratios,
        cmap=color_ch4,
        cbar_ax=cbar_ax1,
    )
    ax2.set_title("CH$_4$ Recall with H$_2$O interference")
    ax2.set_xlabel("$log_{10}$(Mixing Ratio of $H_2O$)")
    ax2.yaxis.set_visible(False)
    ax2.invert_yaxis()
    add_label(ax2, "Interference by $H_2O$")

    # Heatmap 3: O3 Recall with CH4 interference
    ax3 = fig.add_subplot(gs[1, 0])
    sns.heatmap(
        si_O3_sCH4,
        ax=ax3,
        vmin=0,
        vmax=1,
        xticklabels=log_ratios,
        yticklabels=log_ratios,
        cmap=color_o3,
        cbar=False,
    )
    ax3.set_title("O$_3$ Recall with CH$_4$ interference")
    ax3.set_xlabel("$log_{10}$(Mixing Ratio of $CH_4$)")
    ax3.set_ylabel("$log_{10}$(Mixing Ratio of $O_3$)")
    ax3.invert_yaxis()
    add_label(ax3, "Interference by $CH_4$")

    # Heatmap 4: O3 Recall with H2O interference
    ax4 = fig.add_subplot(gs[1, 1], sharey=ax3)
    cbar_ax2 = fig.add_subplot(gs[1, 2])
    sns.heatmap(
        si_O3_sH2O,
        ax=ax4,
        vmin=0,
        vmax=1,
        xticklabels=log_ratios,
        yticklabels=log_ratios,
        cmap=color_o3,
        cbar_ax=cbar_ax2,
    )
    ax4.set_title("O$_3$ Recall with H$_2$O interference")
    ax4.set_xlabel("$log_{10}$(Mixing Ratio of $H_2O$)")
    ax4.set_ylabel("$log_{10}$(Mixing Ratio of $O_3$)")
    ax4.invert_yaxis()
    ax4.yaxis.set_visible(False)
    add_label(ax4, "Interference by $H_2O$")

    # Heatmap 5: H2O Recall with CH4 interference
    ax5 = fig.add_subplot(gs[2, 0])
    sns.heatmap(
        si_H2O_sCH4,
        ax=ax5,
        vmin=0,
        vmax=1,
        xticklabels=log_ratios,
        yticklabels=log_ratios,
        cmap=color_h2o,
        cbar=False,
    )
    ax5.set_title("$H_2O$ Recall with CH$_4$ interference")
    ax5.set_xlabel("$log_{10}$(Mixing Ratio of $CH_4$)")
    ax5.set_ylabel("$log_{10}$(Mixing Ratio of $H_2O$)")
    ax5.invert_yaxis()
    add_label(ax5, "Interference by $CH_4$")

    # Heatmap 6: H2O Recall with O3 interference
    ax6 = fig.add_subplot(gs[2, 1], sharey=ax5)
    cbar_ax3 = fig.add_subplot(gs[2, 2])
    sns.heatmap(
        si_H2O_sO3,
        ax=ax6,
        vmin=0,
        vmax=1,
        xticklabels=log_ratios,
        yticklabels=log_ratios,
        cmap=color_h2o,
        cbar_ax=cbar_ax3,
    )
    ax6.set_title("$H_2O$ Recall with O$_3$ interference")
    ax6.set_xlabel("$log_{10}$(Mixing Ratio of $O_3$)")
    ax6.set_ylabel("$log_{10}$(Mixing Ratio of $H_2O$)")
    ax6.invert_yaxis()
    ax6.yaxis.set_visible(False)
    add_label(ax6, "Interference by $O_3$")

    plt.suptitle(f"Recall for Each Molecule with Interference - SC\nSNR = {SNR}", fontsize=25)
    plt.tight_layout()
    # Uncomment the following line to save the figure:
    # plt.savefig(f"fotos/auto-MC-RecallMap-SNR{SNR}.svg", dpi=300)
    plt.show()
# Out:
# SNR = 3
#  4055/18775 ━━━━━━━━━━━━━━━━━━━━ 17s 1ms/step
# 2025-08-12 19:28:20.579830: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_0_bfc) ran out of memory trying to allocate 64.0KiB (rounded to 65536)requested by op functional_1/dense_1/MatMul
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2025-08-12 19:28:20.583853: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1058] BFCAllocator dump for GPU_0_bfc
# 2025-08-12 19:28:20.584015: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (256): 	Total Chunks: 74, Chunks in use: 73. 18.5KiB allocated for chunks. 18.2KiB in use in bin. 804B client-requested in use in bin.
# 2025-08-12 19:28:20.584047: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-08-12 19:28:20.584050: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (1024): 	Total Chunks: 51, Chunks in use: 49. 70.0KiB allocated for chunks. 67.2KiB in use in bin. 58.6KiB client-requested in use in bin.
# 2025-08-12 19:28:20.584053: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (2048): 	Total Chunks: 87, Chunks in use: 84. 179.8KiB allocated for chunks. 173.0KiB in use in bin. 160.7KiB client-requested in use in bin.
# 2025-08-12 19:28:20.584054: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-08-12 19:28:20.584056: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (8192): 	Total Chunks: 1, Chunks in use: 0. 9.2KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-08-12 19:28:20.584058: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-08-12 19:28:20.584061: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (32768): 	Total Chunks: 4088, Chunks in use: 4086. 192.63MiB allocated for chunks. 192.53MiB in use in bin. 192.03MiB client-requested in use in bin.
# 2025-08-12 19:28:20.584064: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (65536): 	Total Chunks: 12, Chunks in use: 12. 892.2KiB allocated for chunks. 892.2KiB in use in bin. 577.5KiB client-requested in use in bin.
# 2025-08-12 19:28:20.584066: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-08-12 19:28:20.584068: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (262144): 	Total Chunks: 32, Chunks in use: 32. 11.28MiB allocated for chunks. 11.28MiB in use in bin. 10.99MiB client-requested in use in bin.
# 2025-08-12 19:28:20.584070: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (524288): 	Total Chunks: 28, Chunks in use: 28. 20.44MiB allocated for chunks. 20.44MiB in use in bin. 17.43MiB client-requested in use in bin.
# 2025-08-12 19:28:20.584072: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (1048576): 	Total Chunks: 72, Chunks in use: 72. 76.95MiB allocated for chunks. 76.95MiB in use in bin. 64.05MiB client-requested in use in bin.
# 2025-08-12 19:28:20.584074: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-08-12 19:28:20.584076: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-08-12 19:28:20.584077: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-08-12 19:28:20.584079: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-08-12 19:28:20.584081: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-08-12 19:28:20.584082: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-08-12 19:28:20.584085: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-08-12 19:28:20.584087: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (268435456): 	Total Chunks: 1, Chunks in use: 1. 882.37MiB allocated for chunks. 882.37MiB in use in bin. 882.37MiB client-requested in use in bin.
# 2025-08-12 19:28:20.584089: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1081] Bin for 64.0KiB was 64.0KiB, Chunk State:
# 2025-08-12 19:28:20.584238: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1094] Next region of size 1242365952
# 2025-08-12 19:28:20.584409: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98000000 of size 1280 next 1
# 2025-08-12 19:28:20.584412: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98000500 of size 256 next 2
# 2025-08-12 19:28:20.584414: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98000600 of size 256 next 3
# 2025-08-12 19:28:20.584415: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98000700 of size 256 next 4
# 2025-08-12 19:28:20.584416: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98000800 of size 256 next 5
# 2025-08-12 19:28:20.584425: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] Free  at 7fec98000900 of size 2048 next 7
# 2025-08-12 19:28:20.584426: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98001100 of size 256 next 8
# 2025-08-12 19:28:20.584427: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98001200 of size 256 next 6
# 2025-08-12 19:28:20.584428: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98001300 of size 256 next 9
# 2025-08-12 19:28:20.584430: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98001400 of size 49408 next 2236
# 2025-08-12 19:28:20.584433: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9800d500 of size 49408 next 2238
# 2025-08-12 19:28:20.584434: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98019600 of size 49408 next 2239
# 2025-08-12 19:28:20.584436: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98025700 of size 49408 next 2242
# 2025-08-12 19:28:20.584437: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98031800 of size 49408 next 2240
# 2025-08-12 19:28:20.584438: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9803d900 of size 49408 next 2241
# 2025-08-12 19:28:20.584439: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98049a00 of size 49408 next 2243
# 2025-08-12 19:28:20.584440: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98055b00 of size 49408 next 2244
# 2025-08-12 19:28:20.584441: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98061c00 of size 49408 next 2245
# 2025-08-12 19:28:20.584442: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9806dd00 of size 49408 next 2246
# 2025-08-12 19:28:20.584444: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98079e00 of size 49408 next 2247
# 2025-08-12 19:28:20.584445: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98085f00 of size 72192 next 22
# 2025-08-12 19:28:20.584446: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98097900 of size 256 next 24
# 2025-08-12 19:28:20.584447: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98097a00 of size 256 next 23
# 2025-08-12 19:28:20.584448: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98097b00 of size 256 next 25
# 2025-08-12 19:28:20.584450: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] Free  at 7fec98097c00 of size 2304 next 80
# 2025-08-12 19:28:20.584451: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98098500 of size 256 next 39
# 2025-08-12 19:28:20.584453: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] Free  at 7fec98098600 of size 9472 next 49
# 2025-08-12 19:28:20.584454: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9809ab00 of size 256 next 50
# 2025-08-12 19:28:20.584455: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9809ac00 of size 256 next 137
# 2025-08-12 19:28:20.584456: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] Free  at 7fec9809ad00 of size 256 next 53
# 2025-08-12 19:28:20.584457: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9809ae00 of size 256 next 54
# 2025-08-12 19:28:20.584458: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9809af00 of size 49408 next 2262
# 2025-08-12 19:28:20.584459: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec980a7000 of size 49408 next 2263
# 2025-08-12 19:28:20.584461: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec980b3100 of size 49408 next 2264
# 2025-08-12 19:28:20.584462: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec980bf200 of size 49408 next 2267
# 2025-08-12 19:28:20.584463: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec980cb300 of size 49408 next 2265
# 2025-08-12 19:28:20.584464: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec980d7400 of size 49408 next 2266
# 2025-08-12 19:28:20.584465: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec980e3500 of size 49408 next 2268
# 2025-08-12 19:28:20.584466: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec980ef600 of size 49408 next 2270
# 2025-08-12 19:28:20.584467: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec980fb700 of size 49408 next 2269
# 2025-08-12 19:28:20.584468: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98107800 of size 49408 next 2271
# 2025-08-12 19:28:20.584470: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98113900 of size 49408 next 2272
# 2025-08-12 19:28:20.584471: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9811fa00 of size 49408 next 2273
# 2025-08-12 19:28:20.584472: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9812bb00 of size 49408 next 2274
# 2025-08-12 19:28:20.584473: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98137c00 of size 49408 next 2275
# 2025-08-12 19:28:20.584474: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98143d00 of size 49408 next 2276
# 2025-08-12 19:28:20.584475: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9814fe00 of size 49408 next 2277
# 2025-08-12 19:28:20.584476: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9815bf00 of size 49408 next 2278
# 2025-08-12 19:28:20.584477: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98168000 of size 49408 next 2279
# 2025-08-12 19:28:20.584478: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98174100 of size 49408 next 2280
# 2025-08-12 19:28:20.584480: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98180200 of size 49408 next 2281
# 2025-08-12 19:28:20.584481: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9818c300 of size 49408 next 2282
# 2025-08-12 19:28:20.584482: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98198400 of size 49408 next 2283
# 2025-08-12 19:28:20.584483: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec981a4500 of size 49408 next 2284
# 2025-08-12 19:28:20.584484: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec981b0600 of size 49408 next 2285
# 2025-08-12 19:28:20.584486: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec981bc700 of size 49408 next 2286
# 2025-08-12 19:28:20.584487: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec981c8800 of size 49408 next 2287
# 2025-08-12 19:28:20.584488: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec981d4900 of size 49408 next 2288
# 2025-08-12 19:28:20.584489: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec981e0a00 of size 49408 next 2289
# 2025-08-12 19:28:20.584490: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec981ecb00 of size 49408 next 2290
# 2025-08-12 19:28:20.584491: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec981f8c00 of size 49408 next 2291
# 2025-08-12 19:28:20.584492: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98204d00 of size 49408 next 2292
# 2025-08-12 19:28:20.584494: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98210e00 of size 49408 next 2293
# 2025-08-12 19:28:20.584495: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9821cf00 of size 65536 next 2294
# 2025-08-12 19:28:20.584496: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9822cf00 of size 89344 next 12
# 2025-08-12 19:28:20.584497: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98242c00 of size 256 next 14
# 2025-08-12 19:28:20.584498: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] Free  at 7fec98242d00 of size 2560 next 18
# 2025-08-12 19:28:20.584500: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98243700 of size 256 next 21
# 2025-08-12 19:28:20.584501: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98243800 of size 49408 next 4445
# 2025-08-12 19:28:20.584502: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] Free  at 7fec9824f900 of size 54528 next 136
# 2025-08-12 19:28:20.584503: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9825ce00 of size 49408 next 2234
# 2025-08-12 19:28:20.584504: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98268f00 of size 49408 next 2237
# 2025-08-12 19:28:20.584505: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98275000 of size 65536 next 2235
# 2025-08-12 19:28:20.584507: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98285000 of size 93184 next 27
# 2025-08-12 19:28:20.584508: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9829bc00 of size 256 next 29
# 2025-08-12 19:28:20.584509: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9829bd00 of size 49408 next 2373
# 2025-08-12 19:28:20.584510: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec982a7e00 of size 49408 next 2374
# 2025-08-12 19:28:20.584511: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec982b3f00 of size 49408 next 2375
# 2025-08-12 19:28:20.584512: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec982c0000 of size 49408 next 2378
# 2025-08-12 19:28:20.584513: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec982cc100 of size 49408 next 2377
# 2025-08-12 19:28:20.584515: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec982d8200 of size 49408 next 2376
# 2025-08-12 19:28:20.584516: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec982e4300 of size 49408 next 2379
# 2025-08-12 19:28:20.584517: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec982f0400 of size 49408 next 2380
# 2025-08-12 19:28:20.584518: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec982fc500 of size 49408 next 2381
# 2025-08-12 19:28:20.584519: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98308600 of size 49408 next 2382
# 2025-08-12 19:28:20.584521: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98314700 of size 49408 next 2383
# 2025-08-12 19:28:20.584522: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98320800 of size 49408 next 2384
# 2025-08-12 19:28:20.584523: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9832c900 of size 49408 next 2385
# 2025-08-12 19:28:20.584524: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98338a00 of size 49408 next 2386
# 2025-08-12 19:28:20.584525: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98344b00 of size 49408 next 2387
# 2025-08-12 19:28:20.584526: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98350c00 of size 49408 next 2388
# 2025-08-12 19:28:20.584527: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9835cd00 of size 49408 next 2389
# 2025-08-12 19:28:20.584528: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98368e00 of size 49408 next 2390
# 2025-08-12 19:28:20.584530: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98374f00 of size 49408 next 2391
# 2025-08-12 19:28:20.584531: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98381000 of size 49408 next 2392
# 2025-08-12 19:28:20.584532: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9838d100 of size 49408 next 2393
# 2025-08-12 19:28:20.584533: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98399200 of size 49408 next 2394
# 2025-08-12 19:28:20.584534: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec983a5300 of size 49408 next 2395
# 2025-08-12 19:28:20.584535: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec983b1400 of size 49408 next 2396
# 2025-08-12 19:28:20.584536: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec983bd500 of size 49408 next 2398
# 2025-08-12 19:28:20.584537: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec983c9600 of size 49408 next 2397
# 2025-08-12 19:28:20.584539: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec983d5700 of size 49408 next 2399
# 2025-08-12 19:28:20.584540: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec983e1800 of size 49408 next 2400
# 2025-08-12 19:28:20.584541: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec983ed900 of size 49408 next 2401
# 2025-08-12 19:28:20.584542: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec983f9a00 of size 49408 next 2402
# 2025-08-12 19:28:20.584543: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98405b00 of size 49408 next 2403
# 2025-08-12 19:28:20.584544: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98411c00 of size 49408 next 2404
# 2025-08-12 19:28:20.584545: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9841dd00 of size 49408 next 2405
# 2025-08-12 19:28:20.584546: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98429e00 of size 49408 next 2406
# 2025-08-12 19:28:20.584547: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98435f00 of size 49408 next 2407
# 2025-08-12 19:28:20.584549: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98442000 of size 49408 next 2408
# 2025-08-12 19:28:20.584550: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9844e100 of size 49408 next 2411
# 2025-08-12 19:28:20.584551: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9845a200 of size 49408 next 2410
# 2025-08-12 19:28:20.584552: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98466300 of size 49408 next 2409
# 2025-08-12 19:28:20.584554: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98472400 of size 49408 next 2412
# 2025-08-12 19:28:20.584555: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9847e500 of size 49408 next 2413
# 2025-08-12 19:28:20.584556: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9848a600 of size 49408 next 2414
# 2025-08-12 19:28:20.584557: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98496700 of size 49408 next 2415
# 2025-08-12 19:28:20.584558: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec984a2800 of size 49408 next 2416
# 2025-08-12 19:28:20.584559: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec984ae900 of size 49408 next 2417
# 2025-08-12 19:28:20.584560: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec984baa00 of size 49408 next 2418
# 2025-08-12 19:28:20.584561: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec984c6b00 of size 49408 next 2419
# 2025-08-12 19:28:20.584563: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec984d2c00 of size 49408 next 2420
# 2025-08-12 19:28:20.584564: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec984ded00 of size 49408 next 2421
# 2025-08-12 19:28:20.584565: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec984eae00 of size 49408 next 2422
# 2025-08-12 19:28:20.584566: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec984f6f00 of size 49408 next 2423
# 2025-08-12 19:28:20.584567: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98503000 of size 49408 next 2424
# 2025-08-12 19:28:20.584568: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9850f100 of size 49408 next 2425
# 2025-08-12 19:28:20.584569: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9851b200 of size 49408 next 2426
# 2025-08-12 19:28:20.584570: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98527300 of size 49408 next 2427
# 2025-08-12 19:28:20.584572: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98533400 of size 49408 next 2428
# 2025-08-12 19:28:20.584573: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9853f500 of size 49408 next 2429
# 2025-08-12 19:28:20.584574: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9854b600 of size 49408 next 2432
# 2025-08-12 19:28:20.584575: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98557700 of size 49408 next 2433
# 2025-08-12 19:28:20.584576: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98563800 of size 49408 next 2430
# 2025-08-12 19:28:20.584577: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9856f900 of size 49408 next 2435
# 2025-08-12 19:28:20.584578: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9857ba00 of size 49408 next 2431
# 2025-08-12 19:28:20.584579: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98587b00 of size 49408 next 2434
# 2025-08-12 19:28:20.584581: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98593c00 of size 49408 next 2436
# 2025-08-12 19:28:20.584582: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9859fd00 of size 49408 next 2437
# 2025-08-12 19:28:20.584583: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec985abe00 of size 49408 next 2438
# 2025-08-12 19:28:20.584584: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec985b7f00 of size 49408 next 2439
# 2025-08-12 19:28:20.584585: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec985c4000 of size 49408 next 2440
# 2025-08-12 19:28:20.584586: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec985d0100 of size 49408 next 2441
# 2025-08-12 19:28:20.584588: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec985dc200 of size 49408 next 2442
# 2025-08-12 19:28:20.584589: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec985e8300 of size 49408 next 2443
# 2025-08-12 19:28:20.584590: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec985f4400 of size 49408 next 2444
# 2025-08-12 19:28:20.584591: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98600500 of size 49408 next 2445
# 2025-08-12 19:28:20.584592: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9860c600 of size 49408 next 2446
# 2025-08-12 19:28:20.584593: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98618700 of size 49408 next 2447
# 2025-08-12 19:28:20.584594: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98624800 of size 49408 next 2448
# 2025-08-12 19:28:20.584596: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98630900 of size 49408 next 2451
# 2025-08-12 19:28:20.584597: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9863ca00 of size 49408 next 2449
# 2025-08-12 19:28:20.584598: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98648b00 of size 49408 next 2450
# 2025-08-12 19:28:20.584599: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98654c00 of size 49408 next 2452
# 2025-08-12 19:28:20.584600: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98660d00 of size 49408 next 2455
# 2025-08-12 19:28:20.584601: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9866ce00 of size 49408 next 2453
# 2025-08-12 19:28:20.584602: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98678f00 of size 49408 next 2454
# 2025-08-12 19:28:20.584603: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98685000 of size 49408 next 2456
# 2025-08-12 19:28:20.584605: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98691100 of size 49408 next 2459
# 2025-08-12 19:28:20.584606: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9869d200 of size 49408 next 2457
# 2025-08-12 19:28:20.584607: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec986a9300 of size 49408 next 2458
# 2025-08-12 19:28:20.584608: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec986b5400 of size 49408 next 2460
# 2025-08-12 19:28:20.584609: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec986c1500 of size 49408 next 2461
# 2025-08-12 19:28:20.584610: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec986cd600 of size 49408 next 2462
# 2025-08-12 19:28:20.584611: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec986d9700 of size 49408 next 2463
# 2025-08-12 19:28:20.584612: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec986e5800 of size 49408 next 2464
# 2025-08-12 19:28:20.584613: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec986f1900 of size 49408 next 2467
# 2025-08-12 19:28:20.584615: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec986fda00 of size 49408 next 2465
# 2025-08-12 19:28:20.584616: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98709b00 of size 49408 next 2470
# 2025-08-12 19:28:20.584617: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98715c00 of size 49408 next 2469
# 2025-08-12 19:28:20.584618: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98721d00 of size 49408 next 2466
# 2025-08-12 19:28:20.584619: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9872de00 of size 49408 next 2468
# 2025-08-12 19:28:20.584620: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98739f00 of size 49408 next 2471
# 2025-08-12 19:28:20.584622: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98746000 of size 49408 next 2472
# 2025-08-12 19:28:20.584623: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98752100 of size 49408 next 2473
# 2025-08-12 19:28:20.584624: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9875e200 of size 49408 next 2474
# 2025-08-12 19:28:20.584625: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9876a300 of size 49408 next 2475
# 2025-08-12 19:28:20.584627: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98776400 of size 49408 next 2476
# 2025-08-12 19:28:20.584628: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98782500 of size 49408 next 2477
# 2025-08-12 19:28:20.584629: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9878e600 of size 49408 next 2478
# 2025-08-12 19:28:20.584630: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9879a700 of size 49408 next 2479
# 2025-08-12 19:28:20.584631: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec987a6800 of size 49408 next 2480
# 2025-08-12 19:28:20.584632: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec987b2900 of size 49408 next 2481
# 2025-08-12 19:28:20.584633: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec987bea00 of size 49408 next 2482
# 2025-08-12 19:28:20.584634: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec987cab00 of size 49408 next 2483
# 2025-08-12 19:28:20.584637: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec987d6c00 of size 49408 next 2484
# 2025-08-12 19:28:20.584638: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec987e2d00 of size 49408 next 2485
# 2025-08-12 19:28:20.584639: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec987eee00 of size 49408 next 2486
# 2025-08-12 19:28:20.584640: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec987faf00 of size 49408 next 2487
# 2025-08-12 19:28:20.584642: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98807000 of size 49408 next 2488
# 2025-08-12 19:28:20.584643: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98813100 of size 49408 next 2489
# 2025-08-12 19:28:20.584644: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9881f200 of size 49408 next 2490
# 2025-08-12 19:28:20.584645: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9882b300 of size 49408 next 2491
# 2025-08-12 19:28:20.584646: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98837400 of size 49408 next 2492
# 2025-08-12 19:28:20.584647: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98843500 of size 49408 next 2493
# 2025-08-12 19:28:20.584648: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9884f600 of size 49408 next 2496
# 2025-08-12 19:28:20.584649: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9885b700 of size 49408 next 2495
# 2025-08-12 19:28:20.584651: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98867800 of size 49408 next 2494
# 2025-08-12 19:28:20.584652: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98873900 of size 49408 next 2497
# 2025-08-12 19:28:20.584653: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9887fa00 of size 49408 next 2498
# 2025-08-12 19:28:20.584654: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9888bb00 of size 49408 next 2499
# 2025-08-12 19:28:20.584655: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98897c00 of size 49408 next 2500
# 2025-08-12 19:28:20.584656: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec988a3d00 of size 49408 next 2501
# 2025-08-12 19:28:20.584658: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec988afe00 of size 49408 next 2502
# 2025-08-12 19:28:20.584659: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec988bbf00 of size 49408 next 2503
# 2025-08-12 19:28:20.584660: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec988c8000 of size 49408 next 2504
# 2025-08-12 19:28:20.584661: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec988d4100 of size 49408 next 2505
# 2025-08-12 19:28:20.584662: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec988e0200 of size 49408 next 2506
# 2025-08-12 19:28:20.584663: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec988ec300 of size 49408 next 2507
# 2025-08-12 19:28:20.584665: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec988f8400 of size 49408 next 2508
# 2025-08-12 19:28:20.584666: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98904500 of size 49408 next 2509
# 2025-08-12 19:28:20.584667: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98910600 of size 49408 next 2510
# 2025-08-12 19:28:20.584668: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9891c700 of size 49408 next 2511
# 2025-08-12 19:28:20.584669: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98928800 of size 49408 next 2512
# 2025-08-12 19:28:20.584670: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98934900 of size 49408 next 2513
# 2025-08-12 19:28:20.584671: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98940a00 of size 49408 next 2514
# 2025-08-12 19:28:20.584672: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9894cb00 of size 49408 next 2515
# 2025-08-12 19:28:20.584673: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98958c00 of size 49408 next 2516
# 2025-08-12 19:28:20.584675: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98964d00 of size 49408 next 2517
# 2025-08-12 19:28:20.584676: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98970e00 of size 49408 next 2518
# 2025-08-12 19:28:20.584677: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec9897cf00 of size 49408 next 2519
# 2025-08-12 19:28:20.584678: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98989000 of size 49408 next 2520
# 2025-08-12 19:28:20.584679: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98995100 of size 49408 next 2521
# 2025-08-12 19:28:20.584680: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec989a1200 of size 49408 next 2522
# 2025-08-12 19:28:20.584681: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec989ad300 of size 49408 next 2523
# 2025-08-12 19:28:20.584682: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec989b9400 of size 49408 next 2524
# 2025-08-12 19:28:20.584684: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec989c5500 of size 49408 next 2525
# 2025-08-12 19:28:20.584685: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec989d1600 of size 49408 next 2526
# 2025-08-12 19:28:20.584686: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec989dd700 of size 49408 next 2527
# 2025-08-12 19:28:20.584687: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec989e9800 of size 49408 next 2528
# 2025-08-12 19:28:20.584688: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec989f5900 of size 49408 next 2529
# 2025-08-12 19:28:20.584689: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98a01a00 of size 49408 next 2530
# 2025-08-12 19:28:20.584690: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98a0db00 of size 49408 next 2531
# 2025-08-12 19:28:20.584692: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98a19c00 of size 49408 next 2532
# 2025-08-12 19:28:20.584693: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98a25d00 of size 49408 next 2533
# 2025-08-12 19:28:20.584694: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98a31e00 of size 49408 next 2534
# 2025-08-12 19:28:20.584695: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98a3df00 of size 49408 next 2535
# 2025-08-12 19:28:20.584697: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98a4a000 of size 49408 next 2536
# 2025-08-12 19:28:20.584698: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98a56100 of size 49408 next 2537
# 2025-08-12 19:28:20.584699: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98a62200 of size 49408 next 2538
# 2025-08-12 19:28:20.584700: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98a6e300 of size 49408 next 2539
# 2025-08-12 19:28:20.584701: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98a7a400 of size 49408 next 2540
# 2025-08-12 19:28:20.584702: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98a86500 of size 49408 next 2541
# 2025-08-12 19:28:20.584703: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98a92600 of size 49408 next 2542
# 2025-08-12 19:28:20.584704: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98a9e700 of size 49408 next 2543
# 2025-08-12 19:28:20.584706: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98aaa800 of size 49408 next 2544
# 2025-08-12 19:28:20.584707: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98ab6900 of size 49408 next 2545
# 2025-08-12 19:28:20.584708: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98ac2a00 of size 49408 next 2546
# 2025-08-12 19:28:20.584709: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98aceb00 of size 49408 next 2547
# 2025-08-12 19:28:20.584710: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98adac00 of size 49408 next 2548
# 2025-08-12 19:28:20.584711: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98ae6d00 of size 49408 next 2549
# 2025-08-12 19:28:20.584712: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98af2e00 of size 49408 next 2550
# 2025-08-12 19:28:20.584713: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98afef00 of size 49408 next 2551
# 2025-08-12 19:28:20.584714: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98b0b000 of size 49408 next 2552
# 2025-08-12 19:28:20.584716: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98b17100 of size 49408 next 2553
# 2025-08-12 19:28:20.584717: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98b23200 of size 49408 next 2554
# 2025-08-12 19:28:20.584718: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98b2f300 of size 49408 next 2555
# 2025-08-12 19:28:20.584719: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98b3b400 of size 49408 next 2556
# 2025-08-12 19:28:20.584720: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98b47500 of size 49408 next 2557
# 2025-08-12 19:28:20.584721: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98b53600 of size 49408 next 2558
# 2025-08-12 19:28:20.584722: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98b5f700 of size 49408 next 2559
# 2025-08-12 19:28:20.584723: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98b6b800 of size 49408 next 2560
# 2025-08-12 19:28:20.584725: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98b77900 of size 49408 next 2561
# 2025-08-12 19:28:20.584726: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98b83a00 of size 49408 next 2562
# 2025-08-12 19:28:20.584727: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98b8fb00 of size 49408 next 2563
# 2025-08-12 19:28:20.584728: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98b9bc00 of size 49408 next 2564
# 2025-08-12 19:28:20.584730: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98ba7d00 of size 49408 next 2565
# 2025-08-12 19:28:20.584731: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98bb3e00 of size 49408 next 2566
# 2025-08-12 19:28:20.584732: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98bbff00 of size 49408 next 2567
# 2025-08-12 19:28:20.584733: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98bcc000 of size 49408 next 2568
# 2025-08-12 19:28:20.584734: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98bd8100 of size 49408 next 2569
# 2025-08-12 19:28:20.584735: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98be4200 of size 49408 next 2570
# 2025-08-12 19:28:20.584738: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98bf0300 of size 49408 next 2571
# 2025-08-12 19:28:20.584739: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98bfc400 of size 49408 next 2572
# 2025-08-12 19:28:20.584740: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98c08500 of size 49408 next 2573
# 2025-08-12 19:28:20.584741: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98c14600 of size 49408 next 2574
# 2025-08-12 19:28:20.584742: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98c20700 of size 49408 next 2575
# 2025-08-12 19:28:20.584744: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98c2c800 of size 49408 next 2576
# 2025-08-12 19:28:20.584745: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98c38900 of size 49408 next 2577
# 2025-08-12 19:28:20.584746: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98c44a00 of size 49408 next 2578
# 2025-08-12 19:28:20.584748: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98c50b00 of size 49408 next 2579
# 2025-08-12 19:28:20.584750: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98c5cc00 of size 49408 next 2580
# 2025-08-12 19:28:20.584752: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98c68d00 of size 49408 next 2581
# 2025-08-12 19:28:20.584754: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98c74e00 of size 49408 next 2582
# 2025-08-12 19:28:20.584756: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98c80f00 of size 49408 next 2583
# 2025-08-12 19:28:20.584758: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98c8d000 of size 49408 next 2584
# 2025-08-12 19:28:20.584760: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98c99100 of size 49408 next 2585
# 2025-08-12 19:28:20.584762: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98ca5200 of size 49408 next 2586
# 2025-08-12 19:28:20.584763: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98cb1300 of size 49408 next 2587
# 2025-08-12 19:28:20.584764: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98cbd400 of size 49408 next 2588
# 2025-08-12 19:28:20.584765: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98cc9500 of size 49408 next 2589
# 2025-08-12 19:28:20.584766: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98cd5600 of size 49408 next 2592
# 2025-08-12 19:28:20.584767: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98ce1700 of size 49408 next 2590
# 2025-08-12 19:28:20.584769: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98ced800 of size 49408 next 2591
# 2025-08-12 19:28:20.584770: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98cf9900 of size 49408 next 2593
# 2025-08-12 19:28:20.584771: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98d05a00 of size 49408 next 2596
# 2025-08-12 19:28:20.584772: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98d11b00 of size 49408 next 2594
# 2025-08-12 19:28:20.584773: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98d1dc00 of size 49408 next 2595
# 2025-08-12 19:28:20.584774: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98d29d00 of size 49408 next 2597
# 2025-08-12 19:28:20.584776: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98d35e00 of size 49408 next 2598
# 2025-08-12 19:28:20.584777: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98d41f00 of size 49408 next 2599
# 2025-08-12 19:28:20.584779: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98d4e000 of size 49408 next 2600
# 2025-08-12 19:28:20.584781: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98d5a100 of size 49408 next 2601
# 2025-08-12 19:28:20.584783: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98d66200 of size 49408 next 2602
# 2025-08-12 19:28:20.584785: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98d72300 of size 49408 next 2603
# 2025-08-12 19:28:20.584787: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98d7e400 of size 49408 next 2606
# 2025-08-12 19:28:20.584788: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98d8a500 of size 49408 next 2604
# 2025-08-12 19:28:20.584790: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98d96600 of size 49408 next 2605
# 2025-08-12 19:28:20.584792: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98da2700 of size 49408 next 2607
# 2025-08-12 19:28:20.584794: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98dae800 of size 49408 next 2608
# 2025-08-12 19:28:20.584796: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fec98dba900 of size 49408 next 2609
# ...
# 2025-08-12 19:28:20.593250: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fece1fdb900 of size 49408 next 4427
# 2025-08-12 19:28:20.593252: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fece1fe7a00 of size 49408 next 4428
# 2025-08-12 19:28:20.593253: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fece1ff3b00 of size 49408 next 4429
# 2025-08-12 19:28:20.593254: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fece1fffc00 of size 49408 next 4430
# 2025-08-12 19:28:20.593255: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fece200bd00 of size 49408 next 4431
# 2025-08-12 19:28:20.593256: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fece2017e00 of size 49408 next 4432
# 2025-08-12 19:28:20.593257: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fece2023f00 of size 49408 next 4433
# 2025-08-12 19:28:20.593324: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fece2030000 of size 49408 next 4434
# 2025-08-12 19:28:20.593325: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fece203c100 of size 49408 next 4435
# 2025-08-12 19:28:20.593327: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fece2048200 of size 49408 next 4436
# 2025-08-12 19:28:20.593328: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fece2054300 of size 49408 next 4437
# 2025-08-12 19:28:20.593329: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fece2060400 of size 49408 next 4438
# 2025-08-12 19:28:20.593330: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fece206c500 of size 49408 next 4439
# 2025-08-12 19:28:20.593331: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fece2078600 of size 49408 next 4440
# 2025-08-12 19:28:20.593332: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fece2084700 of size 49408 next 4441
# 2025-08-12 19:28:20.593333: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fece2090800 of size 49408 next 4442
# 2025-08-12 19:28:20.593334: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fece209c900 of size 49408 next 4443
# 2025-08-12 19:28:20.593336: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fece20a8a00 of size 65536 next 4444
# 2025-08-12 19:28:20.593338: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fece20b8a00 of size 95744 next 18446744073709551615
# 2025-08-12 19:28:20.593339: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1119]      Summary of in-use Chunks by size:
# 2025-08-12 19:28:20.593350: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 73 Chunks of size 256 totalling 18.2KiB
# 2025-08-12 19:28:20.593351: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 37 Chunks of size 1280 totalling 46.2KiB
# 2025-08-12 19:28:20.593353: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 12 Chunks of size 1792 totalling 21.0KiB
# 2025-08-12 19:28:20.593355: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 80 Chunks of size 2048 totalling 160.0KiB
# 2025-08-12 19:28:20.593356: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 4 Chunks of size 3328 totalling 13.0KiB
# 2025-08-12 19:28:20.593358: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 4085 Chunks of size 49408 totalling 192.48MiB
# 2025-08-12 19:28:20.593360: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 54016 totalling 52.8KiB
# 2025-08-12 19:28:20.593361: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 5 Chunks of size 65536 totalling 320.0KiB
# 2025-08-12 19:28:20.593363: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 72192 totalling 70.5KiB
# 2025-08-12 19:28:20.593364: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 74496 totalling 72.8KiB
# 2025-08-12 19:28:20.593366: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 80384 totalling 78.5KiB
# 2025-08-12 19:28:20.593367: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 80640 totalling 78.8KiB
# 2025-08-12 19:28:20.593368: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 89344 totalling 87.2KiB
# 2025-08-12 19:28:20.593370: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 93184 totalling 91.0KiB
# 2025-08-12 19:28:20.593371: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 95744 totalling 93.5KiB
# 2025-08-12 19:28:20.593373: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 20 Chunks of size 360192 totalling 6.87MiB
# 2025-08-12 19:28:20.593374: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 4 Chunks of size 361472 totalling 1.38MiB
# 2025-08-12 19:28:20.593434: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 4 Chunks of size 367872 totalling 1.40MiB
# 2025-08-12 19:28:20.593436: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 4 Chunks of size 426752 totalling 1.63MiB
# 2025-08-12 19:28:20.593437: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 8 Chunks of size 614400 totalling 4.69MiB
# 2025-08-12 19:28:20.593439: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 16 Chunks of size 788480 totalling 12.03MiB
# 2025-08-12 19:28:20.593440: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 4 Chunks of size 974592 totalling 3.72MiB
# 2025-08-12 19:28:20.593442: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 56 Chunks of size 1048576 totalling 56.00MiB
# 2025-08-12 19:28:20.593444: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 4 Chunks of size 1118464 totalling 4.27MiB
# 2025-08-12 19:28:20.593445: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 4 Chunks of size 1308672 totalling 4.99MiB
# 2025-08-12 19:28:20.593447: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 4 Chunks of size 1402880 totalling 5.35MiB
# 2025-08-12 19:28:20.593448: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 4 Chunks of size 1662976 totalling 6.34MiB
# 2025-08-12 19:28:20.593450: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 925232128 totalling 882.37MiB
# 2025-08-12 19:28:20.593451: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1126] Sum Total of in-use chunks: 1.16GiB
# 2025-08-12 19:28:20.593454: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1128] Total bytes in pool: 1242365952 memory_limit_: 1242365952 available bytes: 0 curr_region_allocation_bytes_: 2484731904
# 2025-08-12 19:28:20.593604: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1133] Stats:
# Limit:                      1242365952
# InUse:                      1242245888
# MaxInUse:                   1242300416
# NumAllocs:                    10742056
# MaxAllocSize:                925232128
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2025-08-12 19:28:20.593796: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:512] ****************************************************************************************************
# 2025-08-12 19:28:20.594292: W tensorflow/core/framework/op_kernel.cc:1857] OP_REQUIRES failed at matmul_op_impl.h:959 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[32,512] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 2025-08-12 19:28:20.594313: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[32,512] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node functional_1/dense_1/MatMul}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[13], line 127
#     116 SNR_X_test = SNR_test_df.iloc[:, -n_points:]
#     118 # ==============================
#     119 # Prediction Strategy:
#     120 # For the common strategy (a single autoencoder and RF model), uncomment:
#    (...)    125 #
#     126 # For the specialized strategy (separate autoencoders and RF models), use:
# --> 127 SNR_X_test_CH4 = CH4_encoder.predict(SNR_X_test)
#     128 SNR_X_test_O3 = O3_encoder.predict(SNR_X_test)
#     129 SNR_X_test_H2O = H2O_encoder.predict(SNR_X_test)
#
# File /mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File /mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node functional_1/dense_1/MatMul defined at (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#
#   File "<frozen runpy>", line 88, in _run_code
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 739, in start
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 211, in start
#
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3100, in run_cell
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3155, in _run_cell
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3367, in run_cell_async
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3612, in run_ast_nodes
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3672, in run_code
#
#   File "/tmp/ipykernel_155894/3803901951.py", line 165, in <module>
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py", line 566, in predict
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py", line 260, in one_step_on_data_distributed
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py", line 250, in one_step_on_data
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py", line 105, in predict_step
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/keras/src/layers/layer.py", line 936, in __call__
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/keras/src/ops/operation.py", line 58, in __call__
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py", line 156, in error_handler
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/keras/src/models/functional.py", line 183, in call
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/keras/src/ops/function.py", line 177, in _run_through_graph
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/keras/src/models/functional.py", line 648, in call
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/keras/src/layers/layer.py", line 936, in __call__
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/keras/src/ops/operation.py", line 58, in __call__
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py", line 156, in error_handler
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/keras/src/layers/core/dense.py", line 151, in call
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/keras/src/ops/numpy.py", line 4021, in matmul
#
#   File "/mnt/Data/chikobara_github/Lumos/.venv311/lib/python3.11/site-packages/keras/src/backend/tensorflow/numpy.py", line 590, in matmul
#
# OOM when allocating tensor with shape[32,512] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node functional_1/dense_1/MatMul}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_one_step_on_data_distributed_3775]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.colors as mcolors
import gc
from sklearn.metrics import accuracy_score

# SNR values (for testing, we use SNR = 3)
SNRS = [3]

# Define stellar contamination values
f_spot_values = [0, 0.01, 0.08, 0.26]
f_fac_values = [0, 0.08, 0.54, 0.70]

factor = 10 / 8

for SNR in SNRS:
    print(f"SNR = {SNR}")

    # Generate noise for this SNR
    noise = mrex.generate_df_SNR_noise(
        df=CO2_data, n_repeat=1, SNR=SNR
    )["noise"][1]

    # Generate noisy datasets (without filtering by f_spot and f_fac yet)
    SNR_test_CO2_data = generate_df_with_noise_std(
        df=CO2_data, n_repeat=5000, noise_std=noise
    )
    SNR_test_CH4_data = generate_df_with_noise_std(
        df=CH4_data, n_repeat=int(250 * factor), noise_std=noise
    )
    SNR_test_O3_data = generate_df_with_noise_std(
        df=O3_data, n_repeat=int(250 * factor), noise_std=noise
    )
    SNR_test_H2O_data = generate_df_with_noise_std(
        df=H2O_data, n_repeat=int(250 * factor), noise_std=noise
    )
    SNR_test_CH4_O3_data = generate_df_with_noise_std(
        df=CH4_O3_data, n_repeat=int(25 * factor * factor), noise_std=noise
    )
    SNR_test_CH4_H2O_data = generate_df_with_noise_std(
        df=CH4_H2O_data, n_repeat=int(25 * factor * factor), noise_std=noise
    )
    SNR_test_O3_H2O_data = generate_df_with_noise_std(
        df=O3_H2O_data, n_repeat=int(25 * factor * factor), noise_std=noise
    )
    SNR_test_CH4_O3_H2O_data = generate_df_with_noise_std(
        df=CH4_O3_H2O_data, n_repeat=int(5 * factor * factor * factor),
        noise_std=noise
    )
    SNR_test_noatm_data = generate_df_with_noise_std(
        df=airless_data, n_repeat=5000, noise_std=noise
    )

    # Concatenate all datasets
    SNR_test_df = pd.concat(
        [
            SNR_test_CO2_data,
            SNR_test_CH4_data,
            SNR_test_O3_data,
            SNR_test_H2O_data,
            SNR_test_CH4_O3_data,
            SNR_test_CH4_H2O_data,
            SNR_test_O3_H2O_data,
            SNR_test_CH4_O3_H2O_data,
            SNR_test_noatm_data,
        ],
        ignore_index=True,
    )

    # Free memory and run garbage collection
    del (SNR_test_CO2_data, SNR_test_CH4_data, SNR_test_O3_data,
         SNR_test_H2O_data, SNR_test_CH4_O3_data, SNR_test_CH4_H2O_data,
         SNR_test_O3_H2O_data, SNR_test_CH4_O3_H2O_data, SNR_test_noatm_data)
    gc.collect()

    SNR_test_df["label"] = SNR_test_df["label"].apply(string_to_list)
    SNR_test_df.iloc[:, -n_points:] = normalize_min_max_by_row(
        SNR_test_df.iloc[:, -n_points:]
    )
    SNR_X_test = SNR_test_df.iloc[:, -n_points:]

    # ===== Prediction Strategy =====
    # For common strategy (a single autoencoder and RF), uncomment:
    # SNR_X_test = encoder.predict(SNR_X_test)
    # CH4_probabilities = rf_CH4.predict_proba(SNR_X_test)[:, 1]
    # O3_probabilities = rf_O3.predict_proba(SNR_X_test)[:, 1]
    # H2O_probabilities = rf_H2O.predict_proba(SNR_X_test)[:, 1]
    #
    # For specialized strategy (separate autoencoders and RF models), use:
    SNR_X_test_CH4 = CH4_encoder.predict(SNR_X_test)
    SNR_X_test_O3 = O3_encoder.predict(SNR_X_test)
    SNR_X_test_H2O = H2O_encoder.predict(SNR_X_test)
    CH4_probabilities = rf_CH4.predict_proba(SNR_X_test_CH4)[:, 1]
    O3_probabilities = rf_O3.predict_proba(SNR_X_test_O3)[:, 1]
    H2O_probabilities = rf_H2O.predict_proba(SNR_X_test_H2O)[:, 1]
    # ===== End Prediction Strategy =====

    # Extract true labels for each molecule
    SNR_test_CH4 = np.array([item[0] for item in SNR_test_df["label"]])
    SNR_test_O3 = np.array([item[1] for item in SNR_test_df["label"]])
    SNR_test_H2O = np.array([item[2] for item in SNR_test_df["label"]])
    SNR_test_df["CH4 label"] = SNR_test_CH4
    SNR_test_df["O3 label"] = SNR_test_O3
    SNR_test_df["H2O label"] = SNR_test_H2O

    # Move the last three columns (labels) to the beginning
    cols = list(SNR_test_df.columns)
    SNR_test_df = SNR_test_df[cols[-3:] + cols[:-3]]

    # Set prediction thresholds based on strategy.
    # Specialized thresholds: CH4=0.33, O3=0.27, H2O=0.43
    # Common thresholds: CH4=0.32, O3=0.24, H2O=0.37
    strategy = "specialized"  # Change to "specialized" if needed
    if strategy == "specialized":
        CH4_threshold = 0.33
        O3_threshold = 0.27
        H2O_threshold = 0.43
    else:
        CH4_threshold = 0.32
        O3_threshold = 0.24
        H2O_threshold = 0.37

    CH4_y_pred = (CH4_probabilities > CH4_threshold).astype(int)
    O3_y_pred = (O3_probabilities > O3_threshold).astype(int)
    H2O_y_pred = (H2O_probabilities > H2O_threshold).astype(int)

    SNR_test_df["CH4 pred"] = CH4_y_pred
    SNR_test_df["O3 pred"] = O3_y_pred
    SNR_test_df["H2O pred"] = H2O_y_pred

    # Define mixing ratio range for further analysis
    mix_ratios = np.array(range(-8, 0))

    # Initialize lists to store accuracy curves for interference analysis
    all_no_CH4_sO3 = []
    all_no_CH4_sH2O = []
    all_no_O3_sCH4 = []
    all_no_O3_sH2O = []
    all_no_H2O_sCH4 = []
    all_no_H2O_sO3 = []
    all_no_CH4_sCO2 = []
    all_no_O3_sCO2 = []
    all_no_H2O_sCO2 = []
    all_no_CH4_noatm = []
    all_no_O3_noatm = []
    all_no_H2O_noatm = []

    def filter_data(df, f_spot_val, f_fac_val):
        """Filter DataFrame by f_spot and f_fac values."""
        return df[(df["f_spot"] == f_spot_val) & (df["f_fac"] == f_fac_val)]

    # Loop over each (f_spot, f_fac) combination
    for f_spot_val in f_spot_values:
        for f_fac_val in f_fac_values:
            df_cont = filter_data(SNR_test_df, f_spot_val, f_fac_val)
            if df_cont.empty:
                continue

            # Temporary arrays for each mixing ratio
            tmp_no_CH4_sO3 = np.zeros(len(mix_ratios))
            tmp_no_CH4_sH2O = np.zeros(len(mix_ratios))
            tmp_no_O3_sCH4 = np.zeros(len(mix_ratios))
            tmp_no_O3_sH2O = np.zeros(len(mix_ratios))
            tmp_no_H2O_sCH4 = np.zeros(len(mix_ratios))
            tmp_no_H2O_sO3 = np.zeros(len(mix_ratios))

            # Compute accuracy for each mixing ratio
            for i, mix in enumerate(mix_ratios):
                permix_no_CH4_sO3 = df_cont[
                    (df_cont["atm O3"] == mix) & (df_cont["atm CH4"] == 0)
                ]
                permix_no_CH4_sH2O = df_cont[
                    (df_cont["atm H2O"] == mix) & (df_cont["atm CH4"] == 0)
                ]
                permix_no_O3_sCH4 = df_cont[
                    (df_cont["atm CH4"] == mix) & (df_cont["atm O3"] == 0)
                ]
                permix_no_O3_sH2O = df_cont[
                    (df_cont["atm H2O"] == mix) & (df_cont["atm O3"] == 0)
                ]
                permix_no_H2O_sCH4 = df_cont[
                    (df_cont["atm CH4"] == mix) & (df_cont["atm H2O"] == 0)
                ]
                permix_no_H2O_sO3 = df_cont[
                    (df_cont["atm O3"] == mix) & (df_cont["atm H2O"] == 0)
                ]
                tmp_no_CH4_sO3[i] = (
                    accuracy_score(permix_no_CH4_sO3["CH4 label"],
                                   permix_no_CH4_sO3["CH4 pred"])
                    if len(permix_no_CH4_sO3) > 0
                    else np.nan
                )
                tmp_no_CH4_sH2O[i] = (
                    accuracy_score(permix_no_CH4_sH2O["CH4 label"],
                                   permix_no_CH4_sH2O["CH4 pred"])
                    if len(permix_no_CH4_sH2O) > 0
                    else np.nan
                )
                tmp_no_O3_sCH4[i] = (
                    accuracy_score(permix_no_O3_sCH4["O3 label"],
                                   permix_no_O3_sCH4["O3 pred"])
                    if len(permix_no_O3_sCH4) > 0
                    else np.nan
                )
                tmp_no_O3_sH2O[i] = (
                    accuracy_score(permix_no_O3_sH2O["O3 label"],
                                   permix_no_O3_sH2O["O3 pred"])
                    if len(permix_no_O3_sH2O) > 0
                    else np.nan
                )
                tmp_no_H2O_sCH4[i] = (
                    accuracy_score(permix_no_H2O_sCH4["H2O label"],
                                   permix_no_H2O_sCH4["H2O pred"])
                    if len(permix_no_H2O_sCH4) > 0
                    else np.nan
                )
                tmp_no_H2O_sO3[i] = (
                    accuracy_score(permix_no_H2O_sO3["H2O label"],
                                   permix_no_H2O_sO3["H2O pred"])
                    if len(permix_no_H2O_sO3) > 0
                    else np.nan
                )

            # Cases for CO2 and no atmosphere (single values)
            val_no_mol_sCO2 = df_cont[
                (df_cont["atm O3"] == 0)
                & (df_cont["atm H2O"] == 0)
                & (df_cont["atm CO2"] == -2)
            ]
            no_CH4_sCO2 = (
                accuracy_score(val_no_mol_sCO2["CH4 label"],
                               val_no_mol_sCO2["CH4 pred"])
                if len(val_no_mol_sCO2) > 0
                else np.nan
            )
            no_O3_sCO2 = (
                accuracy_score(val_no_mol_sCO2["O3 label"],
                               val_no_mol_sCO2["O3 pred"])
                if len(val_no_mol_sCO2) > 0
                else np.nan
            )
            no_H2O_sCO2 = (
                accuracy_score(val_no_mol_sCO2["H2O label"],
                               val_no_mol_sCO2["H2O pred"])
                if len(val_no_mol_sCO2) > 0
                else np.nan
            )

            val_noatm = df_cont[(df_cont["atm CO2"] == 0)]
            no_CH4_noatm = (
                accuracy_score(val_noatm["CH4 label"], val_noatm["CH4 pred"])
                if len(val_noatm) > 0
                else np.nan
            )
            no_O3_noatm = (
                accuracy_score(val_noatm["O3 label"], val_noatm["O3 pred"])
                if len(val_noatm) > 0
                else np.nan
            )
            no_H2O_noatm = (
                accuracy_score(val_noatm["H2O label"], val_noatm["H2O pred"])
                if len(val_noatm) > 0
                else np.nan
            )

            # Append results to lists
            all_no_CH4_sO3.append(tmp_no_CH4_sO3)
            all_no_CH4_sH2O.append(tmp_no_CH4_sH2O)
            all_no_O3_sCH4.append(tmp_no_O3_sCH4)
            all_no_O3_sH2O.append(tmp_no_O3_sH2O)
            all_no_H2O_sCH4.append(tmp_no_H2O_sCH4)
            all_no_H2O_sO3.append(tmp_no_H2O_sO3)
            all_no_CH4_sCO2.append(no_CH4_sCO2)
            all_no_O3_sCO2.append(no_O3_sCO2)
            all_no_H2O_sCO2.append(no_H2O_sCO2)
            all_no_CH4_noatm.append(no_CH4_noatm)
            all_no_O3_noatm.append(no_O3_noatm)
            all_no_H2O_noatm.append(no_H2O_noatm)

    # Convert lists to arrays
    all_no_CH4_sO3 = np.array(all_no_CH4_sO3)
    all_no_CH4_sH2O = np.array(all_no_CH4_sH2O)
    all_no_O3_sCH4 = np.array(all_no_O3_sCH4)
    all_no_O3_sH2O = np.array(all_no_O3_sH2O)
    all_no_H2O_sCH4 = np.array(all_no_H2O_sCH4)
    all_no_H2O_sO3 = np.array(all_no_H2O_sO3)
    all_no_CH4_sCO2 = np.array(all_no_CH4_sCO2)
    all_no_O3_sCO2 = np.array(all_no_O3_sCO2)
    all_no_H2O_sCO2 = np.array(all_no_H2O_sCO2)
    all_no_CH4_noatm = np.array(all_no_CH4_noatm)
    all_no_O3_noatm = np.array(all_no_O3_noatm)
    all_no_H2O_noatm = np.array(all_no_H2O_noatm)

    def min_max_array(arr):
        if arr.size == 0:
            return (np.full(len(mix_ratios), np.nan),
                    np.full(len(mix_ratios), np.nan))
        return (np.nanmin(arr, axis=0), np.nanmax(arr, axis=0))
    
    no_CH4_sO3_min, no_CH4_sO3_max = min_max_array(all_no_CH4_sO3)
    no_CH4_sH2O_min, no_CH4_sH2O_max = min_max_array(all_no_CH4_sH2O)
    no_O3_sCH4_min, no_O3_sCH4_max = min_max_array(all_no_O3_sCH4)
    no_O3_sH2O_min, no_O3_sH2O_max = min_max_array(all_no_O3_sH2O)
    no_H2O_sCH4_min, no_H2O_sCH4_max = min_max_array(all_no_H2O_sCH4)
    no_H2O_sO3_min, no_H2O_sO3_max = min_max_array(all_no_H2O_sO3)

    def single_min_max(arr):
        return (np.nanmin(arr) if arr.size > 0 else np.nan,
                np.nanmax(arr) if arr.size > 0 else np.nan)
    
    no_CH4_sCO2_min, no_CH4_sCO2_max = single_min_max(all_no_CH4_sCO2)
    no_O3_sCO2_min, no_O3_sCO2_max = single_min_max(all_no_O3_sCO2)
    no_H2O_sCO2_min, no_H2O_sCO2_max = single_min_max(all_no_H2O_sCO2)

    no_CH4_noatm_min, no_CH4_noatm_max = single_min_max(all_no_CH4_noatm)
    no_O3_noatm_min, no_O3_noatm_max = single_min_max(all_no_O3_noatm)
    no_H2O_noatm_min, no_H2O_noatm_max = single_min_max(all_no_H2O_noatm)

    # Calculate the base curve (no contamination: f_spot=0, f_fac=0)
    base_df = filter_data(SNR_test_df, 0, 0)
    base_no_CH4_sO3 = np.zeros(len(mix_ratios))
    base_no_CH4_sH2O = np.zeros(len(mix_ratios))
    base_no_O3_sCH4 = np.zeros(len(mix_ratios))
    base_no_O3_sH2O = np.zeros(len(mix_ratios))
    base_no_H2O_sCH4 = np.zeros(len(mix_ratios))
    base_no_H2O_sO3 = np.zeros(len(mix_ratios))

    for i, mix in enumerate(mix_ratios):
        permix_no_CH4_sO3 = base_df[(base_df["atm O3"] == mix) &
                                    (base_df["atm CH4"] == 0)]
        permix_no_CH4_sH2O = base_df[(base_df["atm H2O"] == mix) &
                                     (base_df["atm CH4"] == 0)]
        permix_no_O3_sCH4 = base_df[(base_df["atm CH4"] == mix) &
                                    (base_df["atm O3"] == 0)]
        permix_no_O3_sH2O = base_df[(base_df["atm H2O"] == mix) &
                                    (base_df["atm O3"] == 0)]
        permix_no_H2O_sCH4 = base_df[(base_df["atm CH4"] == mix) &
                                     (base_df["atm H2O"] == 0)]
        permix_no_H2O_sO3 = base_df[(base_df["atm O3"] == mix) &
                                    (base_df["atm H2O"] == 0)]

        base_no_CH4_sO3[i] = (
            accuracy_score(permix_no_CH4_sO3["CH4 label"],
                           permix_no_CH4_sO3["CH4 pred"])
            if len(permix_no_CH4_sO3) > 0 else np.nan
        )
        base_no_CH4_sH2O[i] = (
            accuracy_score(permix_no_CH4_sH2O["CH4 label"],
                           permix_no_CH4_sH2O["CH4 pred"])
            if len(permix_no_CH4_sH2O) > 0 else np.nan
        )
        base_no_O3_sCH4[i] = (
            accuracy_score(permix_no_O3_sCH4["O3 label"],
                           permix_no_O3_sCH4["O3 pred"])
            if len(permix_no_O3_sCH4) > 0 else np.nan
        )
        base_no_O3_sH2O[i] = (
            accuracy_score(permix_no_O3_sH2O["O3 label"],
                           permix_no_O3_sH2O["O3 pred"])
            if len(permix_no_O3_sH2O) > 0 else np.nan
        )
        base_no_H2O_sCH4[i] = (
            accuracy_score(permix_no_H2O_sCH4["H2O label"],
                           permix_no_H2O_sCH4["H2O pred"])
            if len(permix_no_H2O_sCH4) > 0 else np.nan
        )
        base_no_H2O_sO3[i] = (
            accuracy_score(permix_no_H2O_sO3["H2O label"],
                           permix_no_H2O_sO3["H2O pred"])
            if len(permix_no_H2O_sO3) > 0 else np.nan
        )

    val_no_mol_sCO2_base = base_df[
        (base_df["atm O3"] == 0) & (base_df["atm H2O"] == 0) &
        (base_df["atm CO2"] == -2)
    ]
    base_no_CH4_sCO2 = (
        accuracy_score(val_no_mol_sCO2_base["CH4 label"],
                       val_no_mol_sCO2_base["CH4 pred"])
        if len(val_no_mol_sCO2_base) > 0 else np.nan
    )
    base_no_O3_sCO2 = (
        accuracy_score(val_no_mol_sCO2_base["O3 label"],
                       val_no_mol_sCO2_base["O3 pred"])
        if len(val_no_mol_sCO2_base) > 0 else np.nan
    )
    base_no_H2O_sCO2 = (
        accuracy_score(val_no_mol_sCO2_base["H2O label"],
                       val_no_mol_sCO2_base["H2O pred"])
        if len(val_no_mol_sCO2_base) > 0 else np.nan
    )

    val_noatm_base = base_df[(base_df["atm CO2"] == 0)]
    base_no_CH4_noatm = (
        accuracy_score(val_noatm_base["CH4 label"],
                       val_noatm_base["CH4 pred"])
        if len(val_noatm_base) > 0 else np.nan
    )
    base_no_O3_noatm = (
        accuracy_score(val_noatm_base["O3 label"],
                       val_noatm_base["O3 pred"])
        if len(val_noatm_base) > 0 else np.nan
    )
    base_no_H2O_noatm = (
        accuracy_score(val_noatm_base["H2O label"],
                       val_noatm_base["H2O pred"])
        if len(val_noatm_base) > 0 else np.nan
    )

    # Plot results for each molecule's TNR with interference
    fig, ax = plt.subplots(1, 3, figsize=(15, 6), sharey=True)

    # CH4: interference by O3 and H2O
    ax[0].fill_between(mix_ratios, no_CH4_sO3_min, no_CH4_sO3_max,
                       color="#B03A2E", alpha=0.2)
    ax[0].plot(mix_ratios, base_no_CH4_sO3, label="$O_3$", color="#B03A2E")
    ax[0].fill_between(mix_ratios, no_CH4_sH2O_min, no_CH4_sH2O_max,
                       color="#2874A6", alpha=0.2)
    ax[0].plot(mix_ratios, base_no_CH4_sH2O, label="$H_2O$", color="#2874A6")
    if not np.isnan(base_no_CH4_sCO2):
        ax[0].errorbar(-2, base_no_CH4_sCO2,
                       yerr=[[base_no_CH4_sCO2 - no_CH4_sCO2_min],
                             [no_CH4_sCO2_max - base_no_CH4_sCO2]],
                       fmt="*", color="k", capsize=5, label="CO$_2$")
    if not np.isnan(base_no_CH4_noatm):
        ax[0].axhline(base_no_CH4_noatm, color="k", ls=":", alpha=0.8,
                      label="no atm")
        if (not np.isnan(no_CH4_noatm_min) and 
            not np.isnan(no_CH4_noatm_max)):
            ax[0].fill_between(mix_ratios, no_CH4_noatm_min, no_CH4_noatm_max,
                               color="k", alpha=0.1)
    ax[0].set_title("$CH_4$")
    ax[0].fill_between([-9, 1], 0, 0.6, hatch="/", color="purple", alpha=0.05)
    ax[0].set_xlabel("$log_{10}$(Mixing Ratio)")
    ax[0].set_ylabel("Score")
    ax[0].set_xlim(-8, -1)
    ax[0].set_ylim(0, 1)
    ax[0].legend()

    # O3: interference by CH4 and H2O
    ax[1].fill_between(mix_ratios, no_O3_sCH4_min, no_O3_sCH4_max,
                       color="#B7950B", alpha=0.2)
    ax[1].plot(mix_ratios, base_no_O3_sCH4, label="$CH_4$", color="#B7950B")
    ax[1].fill_between(mix_ratios, no_O3_sH2O_min, no_O3_sH2O_max,
                       color="#2874A6", alpha=0.2)
    ax[1].plot(mix_ratios, base_no_O3_sH2O, label="$H_2O$", color="#2874A6")
    if not np.isnan(base_no_O3_sCO2):
        ax[1].errorbar(-2, base_no_O3_sCO2,
                       yerr=[[base_no_O3_sCO2 - no_O3_sCO2_min],
                             [no_O3_sCO2_max - base_no_O3_sCO2]],
                       fmt="*", color="k", capsize=5, label="CO$_2$")
    if not np.isnan(base_no_O3_noatm):
        ax[1].axhline(base_no_O3_noatm, color="k", ls=":", alpha=0.8,
                      label="no atm")
        if (not np.isnan(no_O3_noatm_min) and 
            not np.isnan(no_O3_noatm_max)):
            ax[1].fill_between(mix_ratios, no_O3_noatm_min, no_O3_noatm_max,
                               color="k", alpha=0.1)
    ax[1].set_title("$O_3$")
    ax[1].fill_between([-9, 1], 0, 0.6, hatch="/", color="purple", alpha=0.05)
    ax[1].set_xlabel("$log_{10}$(Mixing Ratio)")
    ax[1].set_xlim(-8, -1)
    ax[1].set_ylim(0, 1)
    ax[1].legend()

    # H2O: interference by CH4 and O3
    ax[2].fill_between(mix_ratios, no_H2O_sCH4_min, no_H2O_sCH4_max,
                       color="#B7950B", alpha=0.2)
    ax[2].plot(mix_ratios, base_no_H2O_sCH4, label="$CH_4$", color="#B7950B")
    ax[2].fill_between(mix_ratios, no_H2O_sO3_min, no_H2O_sO3_max,
                       color="#B03A2E", alpha=0.2)
    ax[2].plot(mix_ratios, base_no_H2O_sO3, label="$O_3$", color="#B03A2E")
    if not np.isnan(base_no_H2O_sCO2):
        ax[2].errorbar(-2, base_no_H2O_sCO2,
                       yerr=[[base_no_H2O_sCO2 - no_H2O_sCO2_min],
                             [no_H2O_sCO2_max - base_no_H2O_sCO2]],
                       fmt="*", color="k", capsize=5, label="CO$_2$")
    if not np.isnan(base_no_H2O_noatm):
        ax[2].axhline(base_no_H2O_noatm, color="k", ls=":", alpha=0.8,
                      label="no atm")
        if (not np.isnan(no_H2O_noatm_min) and 
            not np.isnan(no_H2O_noatm_max)):
            ax[2].fill_between(mix_ratios, no_H2O_noatm_min, no_H2O_noatm_max,
                               color="k", alpha=0.1)
    ax[2].set_title("$H_2O$")
    ax[2].fill_between([-9, 1], 0, 0.6, hatch="/", color="purple", alpha=0.05)
    ax[2].set_xlabel("$log_{10}$(Mixing Ratio)")
    ax[2].set_xlim(-8, -1)
    ax[2].set_ylim(0, 1)
    ax[2].legend()

    plt.suptitle(
        f"TNR for Each Molecule with Interference - SC: Specialized AE\nSNR = {SNR}",
        fontsize=18,
    )
    plt.tight_layout()
    # Uncomment to save the figure:
    # plt.savefig(f"fotos/auto-SC-TNR_SNR{SNR}.png", dpi=300)
    plt.show()
# Out:
# SNR = 3
# 24610/24610 ━━━━━━━━━━━━━━━━━━━━ 112s 5ms/step
# 24610/24610 ━━━━━━━━━━━━━━━━━━━━ 108s 4ms/step
# 24610/24610 ━━━━━━━━━━━━━━━━━━━━ 111s 4ms/step
